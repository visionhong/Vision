# %% [markdown]
# ## 원본 - https://github.com/wandb/examples/blob/master/colabs/pytorch/Organizing_Hyperparameter_Sweeps_in_PyTorch_with_W%26B.ipynb

# %%
# %%capture
# !pip install wandb --upgrade

# workaround to fetch MNIST data
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# %%
import wandb 

wandb.login()
# Out:
# True

# %%
sweep_config = {
    'method': 'random'
}

# %%
metric = {
    'name': 'loss',
    'goal': 'minimize'
}

sweep_config['metric'] = metric

# %%
parameters_dict = {
    'optimizer': {
        'values': ['adam','sgd']
    },
    'fc_layer_size': {
        'values' : [128, 256, 512]
    },
    'dropout': {
        'values' : [0.3, 0.4, 0.5]
    },
}

sweep_config['parameters'] = parameters_dict

# %%
parameters_dict.update({
    'epochs':{
        'value' : 1
    }
})

# %%
import math

parameters_dict.update({
    'learning_rate': {
        'distribution':'uniform',  # 균등분포
        'min': 0,
        'max': 0.1
    },
    'batch_size': {
        'distribution': 'q_log_uniform',  # 양자화된 로그 균일분포   round(X / q) * q을 반환
        'q': 1,
        'min': math.log(32),
        'max': math.log(256),
    }
})

# %%
import pprint

pprint.pprint(sweep_config)
# Out:
# {'method': 'random',
#  'metric': {'goal': 'minimize', 'name': 'loss'},
#  'parameters': {'batch_size': {'distribution': 'q_log_uniform',
#                                'max': 5.545177444479562,
#                                'min': 3.4657359027997265,
#                                'q': 1},
#                 'dropout': {'values': [0.3, 0.4, 0.5]},
#                 'epochs': {'value': 1},
#                 'fc_layer_size': {'values': [128, 256, 512]},
#                 'learning_rate': {'distribution': 'uniform',
#                                   'max': 0.1,
#                                   'min': 0},
#                 'optimizer': {'values': ['adam', 'sgd']}}}

# %% [markdown]
# ### initialize sweep

# %%
sweep_id = wandb.sweep(sweep_config, project='pytorch-sweeps-demo')
# Out:
# Create sweep with ID: luoesn35
# Sweep URL: https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35

# %% [markdown]
# ### run the sweep agent

# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def train(config=None):
    with wandb.init(config=config):
        config = wandb.config

        loader = build_dataset(config.batch_size)
        network = build_network(config.fc_layer_size, config.dropout)
        optimizer = build_optimizer(network, config.optimizer, config.learning_rate)
        
        for epoch in range(config.epochs):
            avg_loss = train_epoch(network, loader, optimizer)
            wandb.log({'loss': avg_loss, 'epoch': epoch})

def train_epoch(network, loader, optimizer):
    cumu_loss = 0
    for _, (data, target) in enumerate(loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()

        loss = F.nll_loss(network(data), target)
        cumu_loss += loss.item()

        loss.backward()
        optimizer.step()

        wandb.log({'batch loss': loss.item()})
    return cumu_loss / len(loader)

# %%
def build_dataset(batch_size):
    transform = transforms.Compose(
        [
         transforms.ToTensor(),
         transforms.Normalize((0.1307,), (0.3081,))
        ]
    )
    dataset = datasets.MNIST(".", train=True, download=True,
                             transform=transform)
    sub_dataset = torch.utils.data.Subset(dataset, indices=range(0, len(dataset), 5))
    loader = torch.utils.data.DataLoader(sub_dataset, batch_size=batch_size)
    return loader

def build_network(fc_layer_size, dropout):
    network = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, fc_layer_size),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(fc_layer_size, 10),
        nn.LogSoftmax(dim=1)
    )
    return network.to(device)

def build_optimizer(network, optimizer, learning_rate):
    if optimizer == 'sgd':
        optimizer = optim.SGD(network.parameters(),
                              lr=learning_rate, momentum=0.9)
    elif optimizer == 'adam':
        optimizer = optim.Adam(network.parameters(),
                               lr=learning_rate)
    return optimizer

# %%
wandb.agent(sweep_id, train, count=5)  # 5번 실험
# Out:
# wandb: Agent Starting Run: e0io0wlm with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.5
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 512
# wandb: 	learning_rate: 0.06441295546831664
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">gentle-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo</a><br/>
#                 Sweep page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35</a><br/>
# Run page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/e0io0wlm" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/e0io0wlm</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210525_155519-e0io0wlm</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 919<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210525_155519-e0io0wlm/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210525_155519-e0io0wlm/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.31236</td></tr><tr><td>_runtime</td><td>11</td></tr><tr><td>_timestamp</td><td>1621958130</td></tr><tr><td>_step</td><td>94</td></tr><tr><td>loss</td><td>0.57186</td></tr><tr><td>epoch</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>█▇▅▃▂▃▂▂▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▂▂▂▁▂▁▂▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅████████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅████████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">gentle-sweep-1</strong>: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/e0io0wlm" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/e0io0wlm</a><br/>
# wandb: Agent Starting Run: 2ny12msn with config:
# wandb: 	batch_size: 243
# wandb: 	dropout: 0.5
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 128
# wandb: 	learning_rate: 0.008477230954651261
# wandb: 	optimizer: sgd
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">misunderstood-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo</a><br/>
#                 Sweep page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35</a><br/>
# Run page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/2ny12msn" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/2ny12msn</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210525_155536-2ny12msn</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 957<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210525_155536-2ny12msn/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210525_155536-2ny12msn/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.48167</td></tr><tr><td>_runtime</td><td>3</td></tr><tr><td>_timestamp</td><td>1621958139</td></tr><tr><td>_step</td><td>50</td></tr><tr><td>loss</td><td>1.24917</td></tr><tr><td>epoch</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>████▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▂▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█████████████████████████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█████████████████████████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">misunderstood-sweep-2</strong>: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/2ny12msn" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/2ny12msn</a><br/>
# wandb: Agent Starting Run: 0ukenish with config:
# wandb: 	batch_size: 70
# wandb: 	dropout: 0.4
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 256
# wandb: 	learning_rate: 0.0065760486786174965
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">easy-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo</a><br/>
#                 Sweep page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35</a><br/>
# Run page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/0ukenish" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/0ukenish</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210525_155545-0ukenish</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 993<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210525_155545-0ukenish/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210525_155545-0ukenish/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>0.59926</td></tr><tr><td>_runtime</td><td>4</td></tr><tr><td>_timestamp</td><td>1621958149</td></tr><tr><td>_step</td><td>172</td></tr><tr><td>loss</td><td>0.50844</td></tr><tr><td>epoch</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>█▄▃▄▂▃▂▂▃▂▂▂▂▂▁▁▂▂▂▂▃▃▁▂▁▂▁▂▁▁▂▂▂▁▁▁▂▁▂▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅████████████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅████████████</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">easy-sweep-3</strong>: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/0ukenish" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/0ukenish</a><br/>
# wandb: Agent Starting Run: 00h8jht7 with config:
# wandb: 	batch_size: 50
# wandb: 	dropout: 0.5
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 512
# wandb: 	learning_rate: 0.0482230846746827
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">colorful-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo</a><br/>
#                 Sweep page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35</a><br/>
# Run page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/00h8jht7" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/00h8jht7</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210525_155554-00h8jht7</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1029<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210525_155554-00h8jht7/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210525_155554-00h8jht7/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>1.67633</td></tr><tr><td>_runtime</td><td>5</td></tr><tr><td>_timestamp</td><td>1621958159</td></tr><tr><td>_step</td><td>240</td></tr><tr><td>loss</td><td>3.21465</td></tr><tr><td>epoch</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">colorful-sweep-4</strong>: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/00h8jht7" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/00h8jht7</a><br/>
# wandb: Agent Starting Run: bwx7gl1j with config:
# wandb: 	batch_size: 184
# wandb: 	dropout: 0.5
# wandb: 	epochs: 1
# wandb: 	fc_layer_size: 128
# wandb: 	learning_rate: 0.08272844726212165
# wandb: 	optimizer: adam
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">cool-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo</a><br/>
#                 Sweep page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/sweeps/luoesn35</a><br/>
# Run page: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/bwx7gl1j" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/bwx7gl1j</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210525_155603-bwx7gl1j</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 1063<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210525_155603-bwx7gl1j/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210525_155603-bwx7gl1j/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>1.60186</td></tr><tr><td>_runtime</td><td>4</td></tr><tr><td>_timestamp</td><td>1621958167</td></tr><tr><td>_step</td><td>66</td></tr><tr><td>loss</td><td>4.64691</td></tr><tr><td>epoch</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>batch loss</td><td>▁▆█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁</td></tr><tr><td>epoch</td><td>▁</td></tr></table><br/>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">cool-sweep-5</strong>: <a href="https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/bwx7gl1j" target="_blank">https://wandb.ai/tjems6498/pytorch-sweeps-demo/runs/bwx7gl1j</a><br/>
