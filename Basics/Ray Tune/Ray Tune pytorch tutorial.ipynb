# %%
# %%capture
# !pip install ray
# !pip install tensorboardX

# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler  # 성능이 떨어지는 시도를 조기에 종료
# Out:
# /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)

# %%
def load_data(data_dir='./data'):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5), (0.5, 0.5, 0.5))
    ])

    trainset = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=transform
    )
    testset = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=transform
    )

    return trainset, testset

# %% [markdown]
# ## Model define

# %%
class Net(nn.Module):
    def __init__(self, l1=120, l2=84):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, l1)
        self.fc2 = nn.Linear(l1, l2)
        self.fc3 = nn.Linear(l2, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train_cifar(config, checkpoint_dir=None, data_dir=None):
    net = Net(config['l1'], config['l2'])
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    if torch.cuda.device_count() > 1:
        net = nn.DataParallel(net)  # 다중 gpu
    net.to(device) 
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=config['lr'], momentum=0.9)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(os.path.join(checkpoint_dir, 'checkpoint'))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, testset = load_data(data_dir)

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(
        trainset, [test_abs, len(trainset) - test_abs]  # 앞이 val 뒤가 train
    )
    
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=4)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=4)
    
    for epoch in range(10):
        running_loss = 0.0
        epoch_steps = 0
        net.train()
        for i, data in enumerate(trainloader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            epoch_steps+=1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0  # 2000 iter만큼의 loss 평균계산

        net.eval()
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                predicted = torch.argmax(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, 'checkpoint')
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy = correct / total)  # validation의 1epoch의 평균 loss와 accuracy
    print("Finished Training")

# %%
def test_accuracy(net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=1):
    data_dir = os.path.abspath('./data')
    load_data(data_dir)

    config= {
    'l1': tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
    'l2': tune.sample_from(lambda _: 2**np.random.randint(2, 9)),
    'lr': tune.loguniform(1e-4, 1e-1),  # 균일하게 샘플링
    'batch_size': tune.choice([2, 4, 8, 16])
    }

    scheduler = ASHAScheduler(
        metric='loss',
        mode='min',
        max_t = max_num_epochs,
        grace_period=1,
        reduction_factor=2
    )
    reporter = CLIReporter(
        metric_columns = ['loss','accuracy','training_iteration']
    )
    result = tune.run(
        partial(train_cifar, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)
    
    best_trial = result.get_best_trial('loss','min','last')
    print('Best trial config: {}'.format(best_trial.config))
    print('Best trial final validation loss: {}'.format(
        best_trial.last_result['loss']
    ))
    print('Best trial final validation accuracy: {}'.format(
        best_trial.last_result['accuracy']
    ))

    best_trained_model = Net(best_trial.config['l1'], best_trial.config['l2'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    if torch.cuda.device_count() > 1:
        best_trained_model = nn.DataParallel(best_trained_model)  # 다중 gpu
    best_trained_model.to(device) 

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, 'checkpoint'
    ))
    best_trained_model.load_state_dict(model_state)

    test_acc = test_accuracy(best_trained_model, device)
    print('Best trial test set accuracy: {}'.format(test_acc))

# %%
if __name__ == '__main__':
    main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting /content/data/cifar-10-python.tar.gz to /content/data
# Files already downloaded and verified
# 2021-06-05 14:44:58,392	INFO services.py:1269 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-06-05 14:44:59,989	WARNING experiment.py:294 -- No name detected on trainable. Using DEFAULT.
# 2021-06-05 14:44:59,991	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Memory usage on this node: 1.5/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_9a930_00000 | RUNNING  |       |            2 |    4 |   32 | 0.0865766   |
# | DEFAULT_9a930_00001 | PENDING  |       |            2 |    4 |  128 | 0.0002696   |
# | DEFAULT_9a930_00002 | PENDING  |       |            8 |  128 |  256 | 0.00268091  |
# | DEFAULT_9a930_00003 | PENDING  |       |            4 |    4 |    4 | 0.000419058 |
# | DEFAULT_9a930_00004 | PENDING  |       |           16 |  128 |   64 | 0.0376192   |
# | DEFAULT_9a930_00005 | PENDING  |       |            4 |  256 |  128 | 0.000128542 |
# | DEFAULT_9a930_00006 | PENDING  |       |            2 |   16 |    4 | 0.000177237 |
# | DEFAULT_9a930_00007 | PENDING  |       |            4 |    4 |    8 | 0.000480923 |
# | DEFAULT_9a930_00008 | PENDING  |       |            4 |    4 |   32 | 0.00143571  |
# | DEFAULT_9a930_00009 | PENDING  |       |            8 |  128 |  128 | 0.00861288  |
# +---------------------+----------+-------+--------------+------+------+-------------+
#
#
# (pid=266) Files already downloaded and verified
# (pid=264) Files already downloaded and verified
# (pid=266) Files already downloaded and verified
# (pid=264) Files already downloaded and verified
# == Status ==
# Memory usage on this node: 2.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (8 PENDING, 2 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_9a930_00000 | RUNNING  |       |            2 |    4 |   32 | 0.0865766   |
# | DEFAULT_9a930_00001 | RUNNING  |       |            2 |    4 |  128 | 0.0002696   |
# | DEFAULT_9a930_00002 | PENDING  |       |            8 |  128 |  256 | 0.00268091  |
# | DEFAULT_9a930_00003 | PENDING  |       |            4 |    4 |    4 | 0.000419058 |
# | DEFAULT_9a930_00004 | PENDING  |       |           16 |  128 |   64 | 0.0376192   |
# | DEFAULT_9a930_00005 | PENDING  |       |            4 |  256 |  128 | 0.000128542 |
# | DEFAULT_9a930_00006 | PENDING  |       |            2 |   16 |    4 | 0.000177237 |
# | DEFAULT_9a930_00007 | PENDING  |       |            4 |    4 |    8 | 0.000480923 |
# | DEFAULT_9a930_00008 | PENDING  |       |            4 |    4 |   32 | 0.00143571  |
# | DEFAULT_9a930_00009 | PENDING  |       |            8 |  128 |  128 | 0.00861288  |
# +---------------------+----------+-------+--------------+------+------+-------------+
#
#
# == Status ==
# Memory usage on this node: 2.0/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (8 PENDING, 2 RUNNING)
# +---------------------+----------+-------+--------------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   l1 |   l2 |          lr |
# |---------------------+----------+-------+--------------+------+------+-------------|
# | DEFAULT_9a930_00000 | RUNNING  |       |            2 |    4 |   32 | 0.0865766   |
# | DEFAULT_9a930_00001 | RUNNING  |       |            2 |    4 |  128 | 0.0002696   |
# | DEFAULT_9a930_00002 | PENDING  |       |            8 |  128 |  256 | 0.00268091  |
# | DEFAULT_9a930_00003 | PENDING  |       |            4 |    4 |    4 | 0.000419058 |
# | DEFAULT_9a930_00004 | PENDING  |       |           16 |  128 |   64 | 0.0376192   |
# | DEFAULT_9a930_00005 | PENDING  |       |            4 |  256 |  128 | 0.000128542 |
# | DEFAULT_9a930_00006 | PENDING  |       |            2 |   16 |    4 | 0.000177237 |
# | DEFAULT_9a930_00007 | PENDING  |       |            4 |    4 |    8 | 0.000480923 |
# | DEFAULT_9a930_00008 | PENDING  |       |            4 |    4 |   32 | 0.00143571  |
# | DEFAULT_9a930_00009 | PENDING  |       |            8 |  128 |  128 | 0.00861288  |
# +---------------------+----------+-------+--------------+------+------+-------------+
#
#
# (pid=266) [1,  2000] loss: 2.305
# (pid=264) [1,  2000] loss: 2.403
# (pid=266) [1,  4000] loss: 1.152
# (pid=264) [1,  4000] loss: 1.207
# (pid=266) [1,  6000] loss: 0.767
# (pid=264) [1,  6000] loss: 0.800
# (pid=266) [1,  8000] loss: 0.561
# (pid=264) [1,  8000] loss: 0.600
# (pid=266) [1, 10000] loss: 0.412
# (pid=264) [1, 10000] loss: 0.480
# (pid=266) [1, 12000] loss: 0.329
# (pid=264) [1, 12000] loss: 0.401
# (pid=266) [1, 14000] loss: 0.270
# (pid=264) [1, 14000] loss: 0.343
# (pid=266) [1, 16000] loss: 0.226
# (pid=264) [1, 16000] loss: 0.300
# (pid=266) [1, 18000] loss: 0.196
# (pid=264) [1, 18000] loss: 0.267
# (pid=266) [1, 20000] loss: 0.172
# (pid=264) [1, 20000] loss: 0.241
# Result for DEFAULT_9a930_00001:
#   accuracy: 0.3501
#   date: 2021-06-05_14-46-27
#   done: false
#   experiment_id: 05ead3153a444f1b99fa66abbb9496fd
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 1.726278514611721
#   node_ip: 172.28.0.2
#   pid: 266
#   should_checkpoint: true
#   time_since_restore: 85.69468951225281
#   time_this_iter_s: 85.69468951225281
#   time_total_s: 85.69468951225281
#   timestamp: 1622904387
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00001
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (8 PENDING, 2 RUNNING)
# +---------------------+----------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status   | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+----------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00000 | RUNNING  |                |            2 |    4 |   32 | 0.0865766   |         |            |                      |
# | DEFAULT_9a930_00001 | RUNNING  | 172.28.0.2:266 |            2 |    4 |  128 | 0.0002696   | 1.72628 |     0.3501 |                    1 |
# | DEFAULT_9a930_00002 | PENDING  |                |            8 |  128 |  256 | 0.00268091  |         |            |                      |
# | DEFAULT_9a930_00003 | PENDING  |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING  |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING  |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING  |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING  |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING  |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING  |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# +---------------------+----------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# Result for DEFAULT_9a930_00000:
#   accuracy: 0.103
#   date: 2021-06-05_14-46-27
#   done: true
#   experiment_id: 27d4eac199af4abb81322ea2ed2aae74
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 2.3710101320028305
#   node_ip: 172.28.0.2
#   pid: 264
#   should_checkpoint: true
#   time_since_restore: 86.17425918579102
#   time_this_iter_s: 86.17425918579102
#   time_total_s: 86.17425918579102
#   timestamp: 1622904387
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00000
#
# (pid=263) Files already downloaded and verified
# (pid=263) Files already downloaded and verified
# (pid=266) [2,  2000] loss: 1.670
# (pid=266) [2,  4000] loss: 0.832
# (pid=263) [1,  2000] loss: 1.952
# (pid=266) [2,  6000] loss: 0.543
# (pid=263) [1,  4000] loss: 0.789
# (pid=266) [2,  8000] loss: 0.406
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.4475
#   date: 2021-06-05_14-47-00
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 1.5559475315093994
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 32.029683113098145
#   time_this_iter_s: 32.029683113098145
#   time_total_s: 32.029683113098145
#   timestamp: 1622904420
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (7 PENDING, 2 RUNNING, 1 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00001 | RUNNING    | 172.28.0.2:266 |            2 |    4 |  128 | 0.0002696   | 1.72628 |     0.3501 |                    1 |
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.55595 |     0.4475 |                    1 |
# | DEFAULT_9a930_00003 | PENDING    |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=266) [2, 10000] loss: 0.319
# (pid=266) [2, 12000] loss: 0.261
# (pid=263) [2,  2000] loss: 1.397
# (pid=266) [2, 14000] loss: 0.222
# (pid=263) [2,  4000] loss: 0.667
# (pid=266) [2, 16000] loss: 0.192
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.5459
#   date: 2021-06-05_14-47-30
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 2
#   loss: 1.2736074038743972
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 61.81484627723694
#   time_this_iter_s: 29.785163164138794
#   time_total_s: 61.81484627723694
#   timestamp: 1622904450
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.2736074038743972 | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (7 PENDING, 2 RUNNING, 1 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00001 | RUNNING    | 172.28.0.2:266 |            2 |    4 |  128 | 0.0002696   | 1.72628 |     0.3501 |                    1 |
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.27361 |     0.5459 |                    2 |
# | DEFAULT_9a930_00003 | PENDING    |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=266) [2, 18000] loss: 0.173
# (pid=266) [2, 20000] loss: 0.152
# (pid=263) [3,  2000] loss: 1.222
# (pid=263) [3,  4000] loss: 0.610
# Result for DEFAULT_9a930_00001:
#   accuracy: 0.4458
#   date: 2021-06-05_14-47-52
#   done: true
#   experiment_id: 05ead3153a444f1b99fa66abbb9496fd
#   hostname: 382b57b17247
#   iterations_since_restore: 2
#   loss: 1.4823007146298885
#   node_ip: 172.28.0.2
#   pid: 266
#   should_checkpoint: true
#   time_since_restore: 170.8852801322937
#   time_this_iter_s: 85.1905906200409
#   time_total_s: 170.8852801322937
#   timestamp: 1622904472
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 9a930_00001
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (7 PENDING, 2 RUNNING, 1 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00001 | RUNNING    | 172.28.0.2:266 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.27361 |     0.5459 |                    2 |
# | DEFAULT_9a930_00003 | PENDING    |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=265) Files already downloaded and verified
# (pid=265) Files already downloaded and verified
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.5501
#   date: 2021-06-05_14-48-00
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 3
#   loss: 1.3123456976294519
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 91.68177795410156
#   time_this_iter_s: 29.866931676864624
#   time_total_s: 91.68177795410156
#   timestamp: 1622904480
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (6 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.31235 |     0.5501 |                    3 |
# | DEFAULT_9a930_00003 | RUNNING    |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=265) [1,  2000] loss: 2.305
# (pid=263) [4,  2000] loss: 1.114
# (pid=265) [1,  4000] loss: 1.128
# (pid=265) [1,  6000] loss: 0.721
# (pid=263) [4,  4000] loss: 0.561
# (pid=265) [1,  8000] loss: 0.521
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.5668
#   date: 2021-06-05_14-48-30
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 4
#   loss: 1.2120213317751884
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 121.96453022956848
#   time_this_iter_s: 30.28275227546692
#   time_total_s: 121.96453022956848
#   timestamp: 1622904510
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.8/25.5 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.726278514611721
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (6 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.21202 |     0.5668 |                    4 |
# | DEFAULT_9a930_00003 | RUNNING    |                |            4 |    4 |    4 | 0.000419058 |         |            |                      |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=265) [1, 10000] loss: 0.401
# (pid=263) [5,  2000] loss: 1.020
# Result for DEFAULT_9a930_00003:
#   accuracy: 0.2468
#   date: 2021-06-05_14-48-43
#   done: true
#   experiment_id: 893e98b8cb3a472ca89faf9b7afa1a24
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 1.9670624036312103
#   node_ip: 172.28.0.2
#   pid: 265
#   should_checkpoint: true
#   time_since_restore: 50.138126373291016
#   time_this_iter_s: 50.138126373291016
#   time_total_s: 50.138126373291016
#   timestamp: 1622904523
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00003
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.8466704591214658
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (6 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.21202 |     0.5668 |                    4 |
# | DEFAULT_9a930_00003 | RUNNING    | 172.28.0.2:265 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | PENDING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# (raylet) /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
# (raylet)   "update your install command.", FutureWarning)
# (pid=907) Files already downloaded and verified
# (pid=907) Files already downloaded and verified
# (pid=263) [5,  4000] loss: 0.531
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.5852
#   date: 2021-06-05_14-49-01
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 5
#   loss: 1.1785512973427772
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 152.491952419281
#   time_this_iter_s: 30.527422189712524
#   time_total_s: 152.491952419281
#   timestamp: 1622904541
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.8466704591214658
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (5 PENDING, 2 RUNNING, 3 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.17855 |     0.5852 |                    5 |
# | DEFAULT_9a930_00004 | RUNNING    |                |           16 |  128 |   64 | 0.0376192   |         |            |                      |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=907) [1,  2000] loss: 2.002
# Result for DEFAULT_9a930_00004:
#   accuracy: 0.2564
#   date: 2021-06-05_14-49-09
#   done: true
#   experiment_id: 457a9cdcc342433c8c4eb9b1ce2bef2e
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 2.0113140754699708
#   node_ip: 172.28.0.2
#   pid: 907
#   should_checkpoint: true
#   time_since_restore: 24.222404718399048
#   time_this_iter_s: 24.222404718399048
#   time_total_s: 24.222404718399048
#   timestamp: 1622904549
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00004
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.9670624036312103
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (5 PENDING, 2 RUNNING, 3 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.17855 |     0.5852 |                    5 |
# | DEFAULT_9a930_00004 | RUNNING    | 172.28.0.2:907 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | PENDING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# (raylet) /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
# (raylet)   "update your install command.", FutureWarning)
# (pid=1051) Files already downloaded and verified
# (pid=263) [6,  2000] loss: 0.966
# (pid=1051) Files already downloaded and verified
# (pid=263) [6,  4000] loss: 0.497
# (pid=1051) [1,  2000] loss: 2.303
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.59
#   date: 2021-06-05_14-49-31
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 6
#   loss: 1.2135483667850495
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 182.64447927474976
#   time_this_iter_s: 30.15252685546875
#   time_total_s: 182.64447927474976
#   timestamp: 1622904571
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.9670624036312103
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (4 PENDING, 2 RUNNING, 4 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.21355 |     0.59   |                    6 |
# | DEFAULT_9a930_00005 | RUNNING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=1051) [1,  4000] loss: 1.149
# (pid=263) [7,  2000] loss: 0.900
# (pid=1051) [1,  6000] loss: 0.764
# (pid=1051) [1,  8000] loss: 0.565
# (pid=263) [7,  4000] loss: 0.468
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.6008
#   date: 2021-06-05_14-50-01
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 7
#   loss: 1.1745223013758659
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 212.4800214767456
#   time_this_iter_s: 29.83554220199585
#   time_total_s: 212.4800214767456
#   timestamp: 1622904601
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 9a930_00002
#
# (pid=1051) [1, 10000] loss: 0.428
# == Status ==
# Memory usage on this node: 1.8/25.5 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.9670624036312103
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (4 PENDING, 2 RUNNING, 4 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.17452 |     0.6008 |                    7 |
# | DEFAULT_9a930_00005 | RUNNING    |                |            4 |  256 |  128 | 0.000128542 |         |            |                      |
# | DEFAULT_9a930_00006 | PENDING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# Result for DEFAULT_9a930_00005:
#   accuracy: 0.258
#   date: 2021-06-05_14-50-08
#   done: true
#   experiment_id: ec5c0fc6a83b48f8a5fcbc032aa28506
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 2.0844801324367523
#   node_ip: 172.28.0.2
#   pid: 1051
#   should_checkpoint: true
#   time_since_restore: 56.68063402175903
#   time_this_iter_s: 56.68063402175903
#   time_total_s: 56.68063402175903
#   timestamp: 1622904608
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00005
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: None | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.9891882395505904
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (4 PENDING, 2 RUNNING, 4 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263  |            8 |  128 |  256 | 0.00268091  | 1.17452 |     0.6008 |                    7 |
# | DEFAULT_9a930_00005 | RUNNING    | 172.28.0.2:1051 |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | PENDING    |                 |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                 |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                 |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                 |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                 |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# (raylet) /usr/local/lib/python3.7/dist-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
# (raylet)   "update your install command.", FutureWarning)
# (pid=1258) Files already downloaded and verified
# (pid=263) [8,  2000] loss: 0.858
# (pid=1258) Files already downloaded and verified
# (pid=1258) [1,  2000] loss: 2.321
# (pid=263) [8,  4000] loss: 0.450
# (pid=1258) [1,  4000] loss: 1.153
# Result for DEFAULT_9a930_00002:
#   accuracy: 0.597
#   date: 2021-06-05_14-50-31
#   done: false
#   experiment_id: 986236757ff3498cbaab052c46b73ebe
#   hostname: 382b57b17247
#   iterations_since_restore: 8
#   loss: 1.2321154302060604
#   node_ip: 172.28.0.2
#   pid: 263
#   should_checkpoint: true
#   time_since_restore: 242.07878518104553
#   time_this_iter_s: 29.598763704299927
#   time_total_s: 242.07878518104553
#   timestamp: 1622904631
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 9a930_00002
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.3779540592521429 | Iter 1.000: -1.9891882395505904
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (3 PENDING, 2 RUNNING, 5 TERMINATED)
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc            |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00002 | RUNNING    | 172.28.0.2:263 |            8 |  128 |  256 | 0.00268091  | 1.23212 |     0.597  |                    8 |
# | DEFAULT_9a930_00006 | RUNNING    |                |            2 |   16 |    4 | 0.000177237 |         |            |                      |
# | DEFAULT_9a930_00007 | PENDING    |                |            4 |    4 |    8 | 0.000480923 |         |            |                      |
# | DEFAULT_9a930_00008 | PENDING    |                |            4 |    4 |   32 | 0.00143571  |         |            |                      |
# | DEFAULT_9a930_00009 | PENDING    |                |            8 |  128 |  128 | 0.00861288  |         |            |                      |
# | DEFAULT_9a930_00000 | TERMINATED |                |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00003 | TERMINATED |                |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |                |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# +---------------------+------------+----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=1258) [1,  6000] loss: 0.762
# (pid=1258) [1,  8000] loss: 0.559
# ...
# | DEFAULT_9a930_00006 | TERMINATED |                 |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |                 |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=1681) [1, 10000] loss: 0.362
# (pid=1766) [2,  2000] loss: 1.523
# Result for DEFAULT_9a930_00008:
#   accuracy: 0.3174
#   date: 2021-06-05_14-53-54
#   done: false
#   experiment_id: 56db200412da44be8ba1c18acc32191c
#   hostname: 382b57b17247
#   iterations_since_restore: 1
#   loss: 1.7542821099996566
#   node_ip: 172.28.0.2
#   pid: 1681
#   should_checkpoint: true
#   time_since_restore: 49.43876338005066
#   time_this_iter_s: 49.43876338005066
#   time_total_s: 49.43876338005066
#   timestamp: 1622904834
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9a930_00008
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.5673164680689573 | Iter 1.000: -1.913810465836525
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (2 RUNNING, 8 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00008 | RUNNING    | 172.28.0.2:1681 |            4 |    4 |   32 | 0.00143571  | 1.75428 |     0.3174 |                    1 |
# | DEFAULT_9a930_00009 | RUNNING    | 172.28.0.2:1766 |            8 |  128 |  128 | 0.00861288  | 1.52222 |     0.4502 |                    1 |
# | DEFAULT_9a930_00000 | TERMINATED |                 |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | TERMINATED |                 |            8 |  128 |  256 | 0.00268091  | 1.24302 |     0.6024 |                   10 |
# | DEFAULT_9a930_00003 | TERMINATED |                 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |                 |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | TERMINATED |                 |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |                 |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=1681) [2,  2000] loss: 1.726
# (pid=1766) [2,  4000] loss: 0.754
# (pid=1681) [2,  4000] loss: 0.833
# Result for DEFAULT_9a930_00009:
#   accuracy: 0.4726
#   date: 2021-06-05_14-54-13
#   done: false
#   experiment_id: 26af2145d3a0426483b72efac5469fb3
#   hostname: 382b57b17247
#   iterations_since_restore: 2
#   loss: 1.505723227262497
#   node_ip: 172.28.0.2
#   pid: 1766
#   should_checkpoint: true
#   time_since_restore: 61.99342727661133
#   time_this_iter_s: 29.81950831413269
#   time_total_s: 61.99342727661133
#   timestamp: 1622904853
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 9a930_00009
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.505723227262497 | Iter 1.000: -1.913810465836525
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (2 RUNNING, 8 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00008 | RUNNING    | 172.28.0.2:1681 |            4 |    4 |   32 | 0.00143571  | 1.75428 |     0.3174 |                    1 |
# | DEFAULT_9a930_00009 | RUNNING    | 172.28.0.2:1766 |            8 |  128 |  128 | 0.00861288  | 1.50572 |     0.4726 |                    2 |
# | DEFAULT_9a930_00000 | TERMINATED |                 |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | TERMINATED |                 |            8 |  128 |  256 | 0.00268091  | 1.24302 |     0.6024 |                   10 |
# | DEFAULT_9a930_00003 | TERMINATED |                 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |                 |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | TERMINATED |                 |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |                 |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# (pid=1681) [2,  6000] loss: 0.546
# (pid=1766) [3,  2000] loss: 1.471
# (pid=1681) [2,  8000] loss: 0.403
# (pid=1766) [3,  4000] loss: 0.748
# (pid=1681) [2, 10000] loss: 0.318
# Result for DEFAULT_9a930_00008:
#   accuracy: 0.3953
#   date: 2021-06-05_14-54-41
#   done: true
#   experiment_id: 56db200412da44be8ba1c18acc32191c
#   hostname: 382b57b17247
#   iterations_since_restore: 2
#   loss: 1.5640783069610595
#   node_ip: 172.28.0.2
#   pid: 1681
#   should_checkpoint: true
#   time_since_restore: 97.16874599456787
#   time_this_iter_s: 47.72998261451721
#   time_total_s: 97.16874599456787
#   timestamp: 1622904881
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 9a930_00008
#
# == Status ==
# Memory usage on this node: 1.9/25.5 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.2120213317751884 | Iter 2.000: -1.5349007671117783 | Iter 1.000: -1.913810465836525
# Resources requested: 4.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (2 RUNNING, 8 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00008 | RUNNING    | 172.28.0.2:1681 |            4 |    4 |   32 | 0.00143571  | 1.56408 |     0.3953 |                    2 |
# | DEFAULT_9a930_00009 | RUNNING    | 172.28.0.2:1766 |            8 |  128 |  128 | 0.00861288  | 1.50572 |     0.4726 |                    2 |
# | DEFAULT_9a930_00000 | TERMINATED |                 |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | TERMINATED |                 |            8 |  128 |  256 | 0.00268091  | 1.24302 |     0.6024 |                   10 |
# | DEFAULT_9a930_00003 | TERMINATED |                 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |                 |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | TERMINATED |                 |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |                 |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# Result for DEFAULT_9a930_00009:
#   accuracy: 0.4781
#   date: 2021-06-05_14-54-42
#   done: false
#   experiment_id: 26af2145d3a0426483b72efac5469fb3
#   hostname: 382b57b17247
#   iterations_since_restore: 3
#   loss: 1.5281924292325975
#   node_ip: 172.28.0.2
#   pid: 1766
#   should_checkpoint: true
#   time_since_restore: 91.68259644508362
#   time_this_iter_s: 29.68916916847229
#   time_total_s: 91.68259644508362
#   timestamp: 1622904882
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 9a930_00009
#
# (pid=1766) [4,  2000] loss: 1.475
# (pid=1766) [4,  4000] loss: 0.741
# 2021-06-05 14:55:06,051	INFO tune.py:549 -- Total run time: 606.07 seconds (605.79 seconds for the tuning loop).
# Result for DEFAULT_9a930_00009:
#   accuracy: 0.4681
#   date: 2021-06-05_14-55-05
#   done: true
#   experiment_id: 26af2145d3a0426483b72efac5469fb3
#   hostname: 382b57b17247
#   iterations_since_restore: 4
#   loss: 1.5232763239383698
#   node_ip: 172.28.0.2
#   pid: 1766
#   should_checkpoint: true
#   time_since_restore: 114.65959119796753
#   time_this_iter_s: 22.97699475288391
#   time_total_s: 114.65959119796753
#   timestamp: 1622904905
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 9a930_00009
#
# == Status ==
# Memory usage on this node: 1.6/25.5 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.367648827856779 | Iter 2.000: -1.5349007671117783 | Iter 1.000: -1.913810465836525
# Resources requested: 2.0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (1 RUNNING, 9 TERMINATED)
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc             |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00009 | RUNNING    | 172.28.0.2:1766 |            8 |  128 |  128 | 0.00861288  | 1.52328 |     0.4681 |                    4 |
# | DEFAULT_9a930_00000 | TERMINATED |                 |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |                 |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | TERMINATED |                 |            8 |  128 |  256 | 0.00268091  | 1.24302 |     0.6024 |                   10 |
# | DEFAULT_9a930_00003 | TERMINATED |                 |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |                 |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |                 |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | TERMINATED |                 |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |                 |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# | DEFAULT_9a930_00008 | TERMINATED |                 |            4 |    4 |   32 | 0.00143571  | 1.56408 |     0.3953 |                    2 |
# +---------------------+------------+-----------------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# == Status ==
# Memory usage on this node: 1.5/25.5 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 8.000: -1.2321154302060604 | Iter 4.000: -1.367648827856779 | Iter 2.000: -1.5349007671117783 | Iter 1.000: -1.913810465836525
# Resources requested: 0/4 CPUs, 0/1 GPUs, 0.0/15.01 GiB heap, 0.0/7.51 GiB objects (0.0/1.0 accelerator_type:P100)
# Result logdir: /root/ray_results/DEFAULT_2021-06-05_14-45-00
# Number of trials: 10/10 (10 TERMINATED)
# +---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------+
# | Trial name          | status     | loc   |   batch_size |   l1 |   l2 |          lr |    loss |   accuracy |   training_iteration |
# |---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------|
# | DEFAULT_9a930_00000 | TERMINATED |       |            2 |    4 |   32 | 0.0865766   | 2.37101 |     0.103  |                    1 |
# | DEFAULT_9a930_00001 | TERMINATED |       |            2 |    4 |  128 | 0.0002696   | 1.4823  |     0.4458 |                    2 |
# | DEFAULT_9a930_00002 | TERMINATED |       |            8 |  128 |  256 | 0.00268091  | 1.24302 |     0.6024 |                   10 |
# | DEFAULT_9a930_00003 | TERMINATED |       |            4 |    4 |    4 | 0.000419058 | 1.96706 |     0.2468 |                    1 |
# | DEFAULT_9a930_00004 | TERMINATED |       |           16 |  128 |   64 | 0.0376192   | 2.01131 |     0.2564 |                    1 |
# | DEFAULT_9a930_00005 | TERMINATED |       |            4 |  256 |  128 | 0.000128542 | 2.08448 |     0.258  |                    1 |
# | DEFAULT_9a930_00006 | TERMINATED |       |            2 |   16 |    4 | 0.000177237 | 1.73456 |     0.3366 |                    2 |
# | DEFAULT_9a930_00007 | TERMINATED |       |            4 |    4 |    8 | 0.000480923 | 1.65233 |     0.3439 |                    2 |
# | DEFAULT_9a930_00008 | TERMINATED |       |            4 |    4 |   32 | 0.00143571  | 1.56408 |     0.3953 |                    2 |
# | DEFAULT_9a930_00009 | TERMINATED |       |            8 |  128 |  128 | 0.00861288  | 1.52328 |     0.4681 |                    4 |
# +---------------------+------------+-------+--------------+------+------+-------------+---------+------------+----------------------+
#
#
# Best trial config: {'l1': 128, 'l2': 256, 'lr': 0.002680911977343709, 'batch_size': 8}
# Best trial final validation loss: 1.2430164043605327
# Best trial final validation accuracy: 0.6024
# Files already downloaded and verified
# Files already downloaded and verified
# Best trial test set accuracy: 0.5942
