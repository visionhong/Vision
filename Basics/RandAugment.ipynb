# %% [markdown]
# <a href="https://colab.research.google.com/github/tjems6498/Basics/blob/master/RandAugment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install randaugment
# Out:
# Requirement already satisfied: randaugment in /usr/local/lib/python3.7/dist-packages (1.0.2)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import os
import torch.nn.functional as F

from randaugment import RandAugment

# %%
class BasicBlock(nn.Module):
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()

    self.conv1 = nn.Conv2d(in_planes, planes, 3, stride, 1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    
    self.conv2 = nn.Conv2d(planes, planes, 3, 1, 1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()

    if stride != 1:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, planes, 1, stride, bias=False),
          nn.BatchNorm2d(planes),
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out


class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    
    self.in_planes = 64
    self.conv1 = nn.Conv2d(3, 64, 3, 1, 1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], 1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], 2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], 2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], 2)
    self.adapPool = nn.AdaptiveAvgPool2d(1)
    self.linear = nn.Linear(512, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1] * (num_blocks - 1)  # 첫 블럭의 stride만 2 혹은 1 나머지 반복은 1
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = self.adapPool(out)
    out = out.view(x.shape[0], -1)
    return self.linear(out)
    

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader

train_transform = transforms.Compose(
    [
     transforms.RandomCrop(32, padding=4),
     transforms.RandomHorizontalFlip(),
     RandAugment(),
     transforms.ToTensor(),
    ]
)

test_transform = transforms.Compose(
    [
     transforms.ToTensor(),
    ]
)


train_dataset = CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_dataset = CIFAR10(root='./data', train=False, download=True, transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
import numpy as np
import pdb

mixup_alpha = 1.0

def mixup_data(x, y):
  lam = np.random.rand()  # 0~1
  batch_size = x.shape[0]
  index = torch.randperm(batch_size).to(device)  # randperm: batch_size 개수만큼 unique random index를 가진 1차원 tensor
  mixed_x = lam * x + (1-lam) * x[index]
  y_a, y_b = y, y[index]
  return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
  return lam * criterion(pred, y_a) + (1-lam) * criterion(pred, y_b)

class LabelSmoothingCrossEntropy(nn.Module):
  def __init__(self):
    super(LabelSmoothingCrossEntropy, self).__init__()

  def forward(self, y, targets, smoothing=0.1):
    confidence = 1. - smoothing
    log_probs = F.log_softmax(y, dim=-1)  # 0에 가까워야 좋음 (loss down)
    true_probs = torch.zeros_like(log_probs)
    true_probs.fill_(smoothing / (y.shape[1] - 1))  # 일단 10개의 라벨 전부 0.1111 로 채움
    true_probs.scatter_(1, targets.data.unsqueeze(1), confidence)  # 각 배치별로 정답의 인덱스값을 0.1111 에서 0.9로 채워줌  # torch.scatter_(dim, index, src)
    return torch.mean(torch.sum(true_probs * -log_probs, dim=-1))

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'checkpoint.pth'

criterion = LabelSmoothingCrossEntropy()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
        correct += current_correct

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)
    


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr /= 10
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 150):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.09174929470809817
# Current batch average train loss: 0.018771713599562645
#
# Current batch: 100
# Current batch average train accuracy: 0.09413442306518412
# Current batch average train loss: 0.018014755100011826
#
# Current batch: 200
# Current batch average train accuracy: 0.1990197580281599
# Current batch average train loss: 0.01760999485850334
#
# Current batch: 300
# Current batch average train accuracy: 0.16640785598185237
# Current batch average train loss: 0.01730077527463436
#
# Total average train accuarcy: 0.14176897829490215
# Total average train loss: 0.01874031137943268
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.2559
# Total average test loss: 0.016480767476558685
# Model Saved!
#
# Time elapsed: 34.84935450553894
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.24382374853359437
# Current batch average train loss: 0.016579438000917435
#
# Current batch: 100
# Current batch average train accuracy: 0.15699976779817612
# Current batch average train loss: 0.016902681440114975
#
# Current batch: 200
# Current batch average train accuracy: 0.17568344263626126
# Current batch average train loss: 0.017446313053369522
#
# Current batch: 300
# Current batch average train accuracy: 0.18541096593758902
# Current batch average train loss: 0.017228644341230392
#
# Total average train accuarcy: 0.2135232349221407
# Total average train loss: 0.01701567542552948
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.3186
# Total average test loss: 0.015585578083992004
# Model Saved!
#
# Time elapsed: 69.19814109802246
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.2665592441898812
# Current batch average train loss: 0.01597815938293934
#
# Current batch: 100
# Current batch average train accuracy: 0.3404057749348405
# Current batch average train loss: 0.015524023212492466
#
# Current batch: 200
# Current batch average train accuracy: 0.2527617946202727
# Current batch average train loss: 0.01658686250448227
#
# Current batch: 300
# Current batch average train accuracy: 0.1998378329799081
# Current batch average train loss: 0.016943275928497314
#
# Total average train accuarcy: 0.26405822722283206
# Total average train loss: 0.016432069764137268
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.2431
# Total average test loss: 0.017151481795310973
# Model Saved!
#
# Time elapsed: 104.5168833732605
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.304281914654804
# Current batch average train loss: 0.01561554241925478
#
# Current batch: 100
# Current batch average train accuracy: 0.26628911864830324
# Current batch average train loss: 0.01641949452459812
#
# Current batch: 200
# Current batch average train accuracy: 0.2816249945516055
# Current batch average train loss: 0.016705527901649475
#
# Current batch: 300
# Current batch average train accuracy: 0.29707335772537213
# Current batch average train loss: 0.016389934346079826
#
# Total average train accuarcy: 0.3023356639923653
# Total average train loss: 0.01593949831008911
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.2013
# Total average test loss: 0.017352254390716554
# Model Saved!
#
# Time elapsed: 139.8253903388977
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.3092904418579085
# Current batch average train loss: 0.015729054808616638
#
# Current batch: 100
# Current batch average train accuracy: 0.2064895966924747
# Current batch average train loss: 0.016781765967607498
#
# Current batch: 200
# Current batch average train accuracy: 0.42444426893111403
# Current batch average train loss: 0.014782135374844074
#
# Current batch: 300
# Current batch average train accuracy: 0.32702249177718967
# Current batch average train loss: 0.016235968098044395
#
# Total average train accuarcy: 0.34205003774084153
# Total average train loss: 0.015459397401809693
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.4104
# Total average test loss: 0.014692256081104279
# Model Saved!
#
# Time elapsed: 175.0364158153534
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.34738652954954957
# Current batch average train loss: 0.015742475166916847
#
# Current batch: 100
# Current batch average train accuracy: 0.2757108708244693
# Current batch average train loss: 0.016073478385806084
#
# Current batch: 200
# Current batch average train accuracy: 0.4290807313827775
# Current batch average train loss: 0.014180638827383518
#
# Current batch: 300
# Current batch average train accuracy: 0.4865776542106563
# Current batch average train loss: 0.01297229714691639
#
# Total average train accuarcy: 0.367316073366691
# Total average train loss: 0.015131762549877166
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.4268
# Total average test loss: 0.013886599624156951
# Model Saved!
#
# Time elapsed: 209.8171510696411
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5185607634529226
# Current batch average train loss: 0.01280682161450386
#
# Current batch: 100
# Current batch average train accuracy: 0.43405258261054286
# Current batch average train loss: 0.013645359314978123
#
# Current batch: 200
# Current batch average train accuracy: 0.5200362596774731
# Current batch average train loss: 0.012774019502103329
#
# Current batch: 300
# Current batch average train accuracy: 0.3625660519064957
# Current batch average train loss: 0.014721546322107315
#
# Total average train accuarcy: 0.4115420217792602
# Total average train loss: 0.014560152263641357
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.5719
# Total average test loss: 0.012191282629966736
# Model Saved!
#
# Time elapsed: 245.1596715450287
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.605233649492962
# Current batch average train loss: 0.011669439263641834
#
# Current batch: 100
# Current batch average train accuracy: 0.5052693729526229
# Current batch average train loss: 0.01361086219549179
#
# Current batch: 200
# Current batch average train accuracy: 0.5911512976992498
# Current batch average train loss: 0.012688764370977879
#
# Current batch: 300
# Current batch average train accuracy: 0.5545263721107886
# Current batch average train loss: 0.012430859729647636
#
# Total average train accuarcy: 0.4333966839858955
# Total average train loss: 0.014279630074501037
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.6565
# Total average test loss: 0.01059131053686142
# Model Saved!
#
# Time elapsed: 280.2181222438812
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.45471411089963426
# Current batch average train loss: 0.014554973691701889
#
# Current batch: 100
# Current batch average train accuracy: 0.38202925972653123
# Current batch average train loss: 0.015054566785693169
#
# Current batch: 200
# Current batch average train accuracy: 0.34413712060827994
# Current batch average train loss: 0.015257952734827995
#
# Current batch: 300
# Current batch average train accuracy: 0.4555654314305663
# Current batch average train loss: 0.014281345531344414
#
# Total average train accuarcy: 0.45131536859452825
# Total average train loss: 0.014052962942123413
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.6127
# Total average test loss: 0.01128494359254837
# Model Saved!
#
# Time elapsed: 315.3577370643616
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6657542227620425
# Current batch average train loss: 0.010836059227585793
#
# Current batch: 100
# Current batch average train accuracy: 0.5508339939224949
# Current batch average train loss: 0.012935428880155087
#
# Current batch: 200
# Current batch average train accuracy: 0.6014493587965044
# Current batch average train loss: 0.011898892931640148
#
# Current batch: 300
# Current batch average train accuracy: 0.6284198680922355
# Current batch average train loss: 0.011622183956205845
#
# Total average train accuarcy: 0.4758342223836771
# Total average train loss: 0.013669775733947754
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.6413
# Total average test loss: 0.01100278434753418
# Model Saved!
#
# Time elapsed: 349.7369315624237
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4166708154705644
# Current batch average train loss: 0.014737693592905998
#
# Current batch: 100
# Current batch average train accuracy: 0.3692239483763454
# Current batch average train loss: 0.015478627756237984
#
# Current batch: 200
# Current batch average train accuracy: 0.4853469391632144
# Current batch average train loss: 0.013780502602458
#
# Current batch: 300
# Current batch average train accuracy: 0.5300113311358248
# Current batch average train loss: 0.013557938858866692
#
# Total average train accuarcy: 0.49653291163758195
# Total average train loss: 0.013415048379898072
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.6594
# Total average test loss: 0.010461659157276154
# Model Saved!
#
# Time elapsed: 384.51934456825256
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.3636356768416436
# Current batch average train loss: 0.015412184409797192
#
# Current batch: 100
# Current batch average train accuracy: 0.4037583260647274
# Current batch average train loss: 0.014641697518527508
#
# Current batch: 200
# Current batch average train accuracy: 0.5227971616664052
# Current batch average train loss: 0.013198159635066986
#
# Current batch: 300
# Current batch average train accuracy: 0.5900569311134776
# Current batch average train loss: 0.0112997405230999
#
# Total average train accuarcy: 0.5154754254475906
# Total average train loss: 0.013173711524009705
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.6789
# Total average test loss: 0.01018375482559204
# Model Saved!
#
# Time elapsed: 420.63536071777344
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.42492631845429485
# Current batch average train loss: 0.014866000041365623
#
# Current batch: 100
# Current batch average train accuracy: 0.5675338825589409
# Current batch average train loss: 0.012413794174790382
#
# Current batch: 200
# Current batch average train accuracy: 0.6308916929290395
# Current batch average train loss: 0.010678235441446304
#
# Current batch: 300
# Current batch average train accuracy: 0.37506487999176186
# Current batch average train loss: 0.015744319185614586
#
# Total average train accuarcy: 0.5243647735416205
# Total average train loss: 0.012982378334999085
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.7621
# Total average test loss: 0.009046372520923614
# Model Saved!
#
# Time elapsed: 457.3434364795685
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.40333341742514384
# Current batch average train loss: 0.015157852321863174
#
# Current batch: 100
# Current batch average train accuracy: 0.5315333546608434
# Current batch average train loss: 0.013226410374045372
#
# Current batch: 200
# Current batch average train accuracy: 0.7049419522589361
# Current batch average train loss: 0.010528529062867165
#
# Current batch: 300
# Current batch average train accuracy: 0.42090975615403975
# Current batch average train loss: 0.013888600282371044
#
# Total average train accuarcy: 0.5385695708187496
# Total average train loss: 0.012803710832595825
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.7565
# Total average test loss: 0.00911006726026535
# Model Saved!
#
# Time elapsed: 493.9759042263031
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6360607301061351
# Current batch average train loss: 0.01144238281995058
#
# Current batch: 100
# Current batch average train accuracy: 0.6542757167938942
# Current batch average train loss: 0.011152366176247597
#
# Current batch: 200
# Current batch average train accuracy: 0.7277298515288344
# Current batch average train loss: 0.010367682203650475
#
# Current batch: 300
# Current batch average train accuracy: 0.6376683939213307
# Current batch average train loss: 0.011203758418560028
#
# Total average train accuarcy: 0.5403539632788426
# Total average train loss: 0.01278464212179184
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.7117
# Total average test loss: 0.00978022162914276
# Model Saved!
#
# Time elapsed: 529.3630855083466
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6143754082363587
# Current batch average train loss: 0.011824805289506912
#
# Current batch: 100
# Current batch average train accuracy: 0.38351665522164763
# Current batch average train loss: 0.014947034418582916
#
# Current batch: 200
# Current batch average train accuracy: 0.6180228708610318
# Current batch average train loss: 0.011901007033884525
#
# Current batch: 300
# Current batch average train accuracy: 0.5733921194436216
# Current batch average train loss: 0.01228836365044117
#
# Total average train accuarcy: 0.5520099145485539
# Total average train loss: 0.012604970102310181
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.7555
# Total average test loss: 0.009075355637073517
# Model Saved!
#
# Time elapsed: 565.1414833068848
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6005944931806242
# Current batch average train loss: 0.012436142191290855
#
# Current batch: 100
# Current batch average train accuracy: 0.4329082675949264
# Current batch average train loss: 0.01460511889308691
#
# Current batch: 200
# Current batch average train accuracy: 0.40944166469867893
# Current batch average train loss: 0.014526558108627796
#
# Current batch: 300
# Current batch average train accuracy: 0.48668775431499023
# Current batch average train loss: 0.013706276193261147
#
# Total average train accuarcy: 0.5443505125149287
# Total average train loss: 0.012700164651870727
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.8011
# Total average test loss: 0.008468244081735611
# Model Saved!
#
# Time elapsed: 600.6792306900024
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7430442788743385
# Current batch average train loss: 0.009322592057287693
#
# Current batch: 100
# Current batch average train accuracy: 0.799124850749752
# Current batch average train loss: 0.00805582944303751
#
# Current batch: 200
# Current batch average train accuracy: 0.5600798690808895
# Current batch average train loss: 0.012695316225290298
#
# Current batch: 300
# Current batch average train accuracy: 0.5476989635871726
# Current batch average train loss: 0.013307236135005951
#
# Total average train accuarcy: 0.5635330196510292
# Total average train loss: 0.012438946266174316
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.8002
# Total average test loss: 0.008390080279111862
# Model Saved!
#
# Time elapsed: 637.3578903675079
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5328529959153985
# Current batch average train loss: 0.012944893911480904
#
# Current batch: 100
# Current batch average train accuracy: 0.458763490917298
# Current batch average train loss: 0.01427141111344099
#
# Current batch: 200
# Current batch average train accuracy: 0.41006892911524434
# Current batch average train loss: 0.014463515020906925
#
# Current batch: 300
# Current batch average train accuracy: 0.39221258212452237
# Current batch average train loss: 0.014781752601265907
#
# Total average train accuarcy: 0.5707975413853364
# Total average train loss: 0.01232407402396202
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8161
# Total average test loss: 0.008240463280677795
# Model Saved!
#
# Time elapsed: 673.9521832466125
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6728093395185745
# Current batch average train loss: 0.010644005611538887
#
# Current batch: 100
# Current batch average train accuracy: 0.5576639013274068
# Current batch average train loss: 0.012640396133065224
#
# Current batch: 200
# Current batch average train accuracy: 0.6565609701605662
# Current batch average train loss: 0.010656056925654411
#
# Current batch: 300
# Current batch average train accuracy: 0.5935198521085848
# Current batch average train loss: 0.012240704149007797
#
# Total average train accuarcy: 0.5789878393214218
# Total average train loss: 0.012184564524888992
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.7822
# Total average test loss: 0.008748011755943298
# Model Saved!
#
# Time elapsed: 710.0998508930206
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5251663547490945
# Current batch average train loss: 0.01340990699827671
#
# Current batch: 100
# Current batch average train accuracy: 0.695641036552161
# Current batch average train loss: 0.009892502799630165
#
# Current batch: 200
# Current batch average train accuracy: 0.5372530532038369
# Current batch average train loss: 0.012876743450760841
#
# Current batch: 300
# Current batch average train accuracy: 0.7404811585123686
# Current batch average train loss: 0.009037505835294724
#
# Total average train accuarcy: 0.5807854272905874
# Total average train loss: 0.012166336801052094
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.7963
# Total average test loss: 0.008430213522911071
# Model Saved!
#
# Time elapsed: 746.037743806839
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7166343970759581
# Current batch average train loss: 0.010576735250651836
#
# Current batch: 100
# Current batch average train accuracy: 0.4112054062667706
# Current batch average train loss: 0.01448965072631836
#
# Current batch: 200
# Current batch average train accuracy: 0.8309606017828088
# Current batch average train loss: 0.00757780484855175
#
# Current batch: 300
# Current batch average train accuracy: 0.4016535977196376
# Current batch average train loss: 0.014663025736808777
#
# Total average train accuarcy: 0.5763730651164668
# Total average train loss: 0.012241680814027786
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.6232
# Total average test loss: 0.01097485990524292
# Model Saved!
#
# Time elapsed: 782.0949048995972
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7439455545095829
# Current batch average train loss: 0.009640693664550781
#
# Current batch: 100
# Current batch average train accuracy: 0.4331076770740606
# Current batch average train loss: 0.014593610540032387
#
# Current batch: 200
# Current batch average train accuracy: 0.5280262887805984
# Current batch average train loss: 0.013006223365664482
#
# Current batch: 300
# Current batch average train accuracy: 0.500306429301661
# Current batch average train loss: 0.013473588973283768
#
# Total average train accuarcy: 0.5836050639435305
# Total average train loss: 0.012128182682991028
#
# [ Test epoch: 22 ]
#
# Total average test accuarcy: 0.8386
# Total average test loss: 0.00791856682896614
# Model Saved!
#
# Time elapsed: 818.1975157260895
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.540365006184136
# Current batch average train loss: 0.013077497482299805
#
# Current batch: 100
# Current batch average train accuracy: 0.4173520992988733
# Current batch average train loss: 0.014423537999391556
#
# Current batch: 200
# Current batch average train accuracy: 0.7166980381861315
# Current batch average train loss: 0.010296390391886234
#
# Current batch: 300
# Current batch average train accuracy: 0.5234012665331859
# Current batch average train loss: 0.01327524147927761
#
# Total average train accuarcy: 0.5766579128613002
# Total average train loss: 0.012215177142620087
#
# [ Test epoch: 23 ]
#
# Total average test accuarcy: 0.8058
# Total average test loss: 0.008573493134975433
# Model Saved!
#
# Time elapsed: 855.0561258792877
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.45652432090650286
# Current batch average train loss: 0.014200573787093163
#
# Current batch: 100
# Current batch average train accuracy: 0.6160011200629867
# Current batch average train loss: 0.011622237972915173
#
# Current batch: 200
# Current batch average train accuracy: 0.7893860571982293
# Current batch average train loss: 0.008166242390871048
#
# Current batch: 300
# Current batch average train accuracy: 0.4633409917258842
# Current batch average train loss: 0.013845202513039112
#
# Total average train accuarcy: 0.5903324244754908
# Total average train loss: 0.012003691042661666
#
# [ Test epoch: 24 ]
#
# Total average test accuarcy: 0.7973
# Total average test loss: 0.008188431477546693
# Model Saved!
#
# Time elapsed: 891.1087293624878
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.36353223253931055
# Current batch average train loss: 0.015260155312716961
#
# Current batch: 100
# Current batch average train accuracy: 0.6330220655349411
# Current batch average train loss: 0.01210009679198265
#
# Current batch: 200
# Current batch average train accuracy: 0.612019125322723
# Current batch average train loss: 0.0122219268232584
#
# Current batch: 300
# Current batch average train accuracy: 0.8762414924185559
# Current batch average train loss: 0.007475932128727436
#
# Total average train accuarcy: 0.5848779613285354
# Total average train loss: 0.012117188346385956
#
# [ Test epoch: 25 ]
#
# Total average test accuarcy: 0.8221
# Total average test loss: 0.008095973962545395
# Model Saved!
#
# Time elapsed: 927.4426507949829
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6650196139837433
# Current batch average train loss: 0.011084793135523796
#
# Current batch: 100
# Current batch average train accuracy: 0.46517126079173304
# Current batch average train loss: 0.014300551265478134
#
# Current batch: 200
# Current batch average train accuracy: 0.5637489921702361
# Current batch average train loss: 0.012846751138567924
#
# Current batch: 300
# Current batch average train accuracy: 0.4103708729028619
# Current batch average train loss: 0.014762021601200104
#
# Total average train accuarcy: 0.6063409164478073
# Total average train loss: 0.011796956218481064
#
# [ Test epoch: 26 ]
#
# Total average test accuarcy: 0.8473
# Total average test loss: 0.007259450715780259
# Model Saved!
#
# Time elapsed: 963.4917159080505
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6082129825531122
# Current batch average train loss: 0.012367394752800465
#
# Current batch: 100
# Current batch average train accuracy: 0.3676033722837269
# Current batch average train loss: 0.015558784827589989
#
# Current batch: 200
# Current batch average train accuracy: 0.7240784155738546
# Current batch average train loss: 0.010442055761814117
#
# Current batch: 300
# Current batch average train accuracy: 0.7292192992443826
# Current batch average train loss: 0.009876392781734467
#
# Total average train accuarcy: 0.6071464505234854
# Total average train loss: 0.01176731982588768
#
# [ Test epoch: 27 ]
#
# Total average test accuarcy: 0.799
# Total average test loss: 0.008339380663633347
# Model Saved!
#
# Time elapsed: 999.6432068347931
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.39117147497247773
# Current batch average train loss: 0.014370687305927277
#
# Current batch: 100
# Current batch average train accuracy: 0.5714703055480105
# Current batch average train loss: 0.01269533671438694
#
# Current batch: 200
# Current batch average train accuracy: 0.7775531849470861
# Current batch average train loss: 0.008616894483566284
#
# Current batch: 300
# Current batch average train accuracy: 0.6379240880520326
# Current batch average train loss: 0.011375544592738152
#
# Total average train accuarcy: 0.5969200813880836
# Total average train loss: 0.011908977707624436
#
# [ Test epoch: 28 ]
#
# Total average test accuarcy: 0.8417
# Total average test loss: 0.007824571412801743
# Model Saved!
#
# Time elapsed: 1035.521754026413
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6727641102664558
# Current batch average train loss: 0.01120059285312891
#
# Current batch: 100
# Current batch average train accuracy: 0.6439785951343097
# Current batch average train loss: 0.011742506176233292
#
# Current batch: 200
# Current batch average train accuracy: 0.7009044352179687
# Current batch average train loss: 0.009585818275809288
#
# Current batch: 300
# Current batch average train accuracy: 0.4656605194609623
# Current batch average train loss: 0.013994651846587658
#
# Total average train accuarcy: 0.5950666111724078
# Total average train loss: 0.011960180424451829
#
# [ Test epoch: 29 ]
#
# Total average test accuarcy: 0.8313
# Total average test loss: 0.007924926769733429
# Model Saved!
#
# Time elapsed: 1071.4624953269958
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6460753273071594
# Current batch average train loss: 0.012000473216176033
#
# Current batch: 100
# Current batch average train accuracy: 0.7803415714770734
# Current batch average train loss: 0.00844491459429264
#
# Current batch: 200
# Current batch average train accuracy: 0.5659923259947168
# Current batch average train loss: 0.012755783274769783
#
# Current batch: 300
# Current batch average train accuracy: 0.7167531654835348
# Current batch average train loss: 0.010164346545934677
#
# Total average train accuarcy: 0.6021451018846398
# Total average train loss: 0.011846508769989014
#
# [ Test epoch: 30 ]
#
# Total average test accuarcy: 0.8531
# Total average test loss: 0.007684724378585815
# Model Saved!
#
# Time elapsed: 1107.3390243053436
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.47778409599053756
# Current batch average train loss: 0.013836612924933434
#
# Current batch: 100
# Current batch average train accuracy: 0.6646331625206519
# Current batch average train loss: 0.011085952632129192
#
# Current batch: 200
# Current batch average train accuracy: 0.7540846803005755
# Current batch average train loss: 0.009813521057367325
#
# Current batch: 300
# Current batch average train accuracy: 0.6159160370902755
# Current batch average train loss: 0.0117765748873353
#
# Total average train accuarcy: 0.6026777493100868
# Total average train loss: 0.011809587342739106
#
# [ Test epoch: 31 ]
#
# Total average test accuarcy: 0.8547
# Total average test loss: 0.007892563009262084
# Model Saved!
#
# Time elapsed: 1143.807106256485
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7180971841758742
# Current batch average train loss: 0.009996626526117325
#
# Current batch: 100
# Current batch average train accuracy: 0.4984679596406728
# Current batch average train loss: 0.01380470022559166
#
# Current batch: 200
# Current batch average train accuracy: 0.544025380240237
# Current batch average train loss: 0.013418388552963734
#
# Current batch: 300
# Current batch average train accuracy: 0.7657306491425964
# Current batch average train loss: 0.008561343885958195
#
# Total average train accuarcy: 0.6028378006283612
# Total average train loss: 0.011813473559617996
#
# [ Test epoch: 32 ]
#
# Total average test accuarcy: 0.8457
# Total average test loss: 0.00754847531914711
# Model Saved!
#
# Time elapsed: 1180.428290605545
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6934645057328332
# Current batch average train loss: 0.010431082919239998
#
# Current batch: 100
# Current batch average train accuracy: 0.4387304788410529
# Current batch average train loss: 0.014278830029070377
#
# Current batch: 200
# Current batch average train accuracy: 0.8490863735076583
# Current batch average train loss: 0.007704518735408783
#
# Current batch: 300
# Current batch average train accuracy: 0.6071873426394045
# Current batch average train loss: 0.011941788718104362
#
# Total average train accuarcy: 0.598911275531806
# Total average train loss: 0.011879433811903
#
# [ Test epoch: 33 ]
#
# Total average test accuarcy: 0.8296
# Total average test loss: 0.008013495820760727
# Model Saved!
#
# Time elapsed: 1216.5867848396301
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.676957292063936
# Current batch average train loss: 0.011096585541963577
#
# Current batch: 100
# Current batch average train accuracy: 0.6397386032974481
# Current batch average train loss: 0.011590035632252693
#
# Current batch: 200
# Current batch average train accuracy: 0.6798998510292787
# Current batch average train loss: 0.011080616153776646
#
# Current batch: 300
# Current batch average train accuracy: 0.8138219577166708
# Current batch average train loss: 0.008699651807546616
#
# Total average train accuarcy: 0.6234729855554643
# Total average train loss: 0.011542825032472611
#
# [ Test epoch: 34 ]
#
# Total average test accuarcy: 0.8695
# Total average test loss: 0.007250839173793793
# Model Saved!
#
# Time elapsed: 1252.4239301681519
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6990166236652237
# Current batch average train loss: 0.010524651035666466
#
# Current batch: 100
# Current batch average train accuracy: 0.708959914850238
# Current batch average train loss: 0.009657769463956356
#
# Current batch: 200
# Current batch average train accuracy: 0.5188199692335254
# Current batch average train loss: 0.013272395357489586
#
# Current batch: 300
# Current batch average train accuracy: 0.5265912094061842
# Current batch average train loss: 0.013678798452019691
#
# Total average train accuarcy: 0.6144834904406077
# Total average train loss: 0.011645916011333466
#
# [ Test epoch: 35 ]
#
# Total average test accuarcy: 0.8095
# Total average test loss: 0.008180147695541382
# Model Saved!
#
# Time elapsed: 1288.7330236434937
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.683431348208793
# Current batch average train loss: 0.011201195418834686
#
# Current batch: 100
# Current batch average train accuracy: 0.7071111829504413
# Current batch average train loss: 0.01003873161971569
#
# Current batch: 200
# Current batch average train accuracy: 0.8117937312449687
# Current batch average train loss: 0.008140130899846554
#
# Current batch: 300
# Current batch average train accuracy: 0.7009112116490562
# Current batch average train loss: 0.010486701503396034
#
# Total average train accuarcy: 0.6115634071167936
# Total average train loss: 0.011760957381725312
#
# [ Test epoch: 36 ]
#
# Total average test accuarcy: 0.8451
# Total average test loss: 0.0076789215266704555
# Model Saved!
#
# Time elapsed: 1324.7508311271667
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.49388020376352715
# Current batch average train loss: 0.013562623411417007
#
# Current batch: 100
# Current batch average train accuracy: 0.46895006241582626
# Current batch average train loss: 0.01402570866048336
#
# Current batch: 200
# Current batch average train accuracy: 0.7136120343352144
# Current batch average train loss: 0.010206183418631554
#
# Current batch: 300
# Current batch average train accuracy: 0.6647862835047418
# Current batch average train loss: 0.010817990638315678
#
# Total average train accuarcy: 0.6084465325342207
# Total average train loss: 0.011743049112558366
#
# [ Test epoch: 37 ]
#
# Total average test accuarcy: 0.8576
# Total average test loss: 0.007508088630437851
# Model Saved!
#
# Time elapsed: 1360.6159048080444
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.456106137738655
# Current batch average train loss: 0.014160258695483208
#
# Current batch: 100
# Current batch average train accuracy: 0.5709164890268615
# Current batch average train loss: 0.012569831684231758
#
# Current batch: 200
# Current batch average train accuracy: 0.6564521012223486
# Current batch average train loss: 0.011291594244539738
#
# Current batch: 300
# Current batch average train accuracy: 0.6238388499141597
# Current batch average train loss: 0.011722799390554428
#
# Total average train accuarcy: 0.6015649684557637
# Total average train loss: 0.011846808500289917
#
# [ Test epoch: 38 ]
#
# Total average test accuarcy: 0.8451
# Total average test loss: 0.0076666807413101196
# Model Saved!
#
# Time elapsed: 1396.4588661193848
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6711400436636047
# Current batch average train loss: 0.011283677071332932
#
# Current batch: 100
# Current batch average train accuracy: 0.42044491242104465
# Current batch average train loss: 0.014364805072546005
#
# Current batch: 200
# Current batch average train accuracy: 0.4672825326458983
# Current batch average train loss: 0.0138775035738945
#
# Current batch: 300
# Current batch average train accuracy: 0.7137256579766061
# Current batch average train loss: 0.009781382977962494
#
# Total average train accuarcy: 0.6162217280781705
# Total average train loss: 0.011603647388219833
#
# [ Test epoch: 39 ]
#
# Total average test accuarcy: 0.832
# Total average test loss: 0.007833529448509216
# Model Saved!
#
# Time elapsed: 1432.349191904068
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5309630657694855
# Current batch average train loss: 0.01282260101288557
#
# Current batch: 100
# Current batch average train accuracy: 0.5521116062219483
# Current batch average train loss: 0.012925931252539158
#
# Current batch: 200
# Current batch average train accuracy: 0.7180132209450446
# Current batch average train loss: 0.010788451880216599
#
# Current batch: 300
# Current batch average train accuracy: 0.6160339187200587
# Current batch average train loss: 0.011775451712310314
#
# Total average train accuarcy: 0.6083516353619148
# Total average train loss: 0.011708346836566925
#
# [ Test epoch: 40 ]
#
# Total average test accuarcy: 0.85
# Total average test loss: 0.007563653635978699
# Model Saved!
#
# Time elapsed: 1468.5223121643066
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4976609097524257
# Current batch average train loss: 0.013555815443396568
#
# Current batch: 100
# Current batch average train accuracy: 0.5534848684489202
# Current batch average train loss: 0.013071669265627861
#
# Current batch: 200
# Current batch average train accuracy: 0.5481413031787961
# Current batch average train loss: 0.013217614963650703
#
# Current batch: 300
# Current batch average train accuracy: 0.597640568929486
# Current batch average train loss: 0.012109043076634407
#
# Total average train accuarcy: 0.6153964845666505
# Total average train loss: 0.01166818383216858
#
# [ Test epoch: 41 ]
#
# Total average test accuarcy: 0.8447
# Total average test loss: 0.007855832523107528
# Model Saved!
#
# Time elapsed: 1504.811429977417
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6375846693068575
# Current batch average train loss: 0.01129780150949955
#
# Current batch: 100
# Current batch average train accuracy: 0.5167493613850747
# Current batch average train loss: 0.013489979319274426
#
# Current batch: 200
# Current batch average train accuracy: 0.6519269625643782
# Current batch average train loss: 0.011476466432213783
#
# Current batch: 300
# Current batch average train accuracy: 0.4863649381076513
# Current batch average train loss: 0.013781776651740074
#
# Total average train accuarcy: 0.6172316216199514
# Total average train loss: 0.01162573827624321
#
# [ Test epoch: 42 ]
#
# Total average test accuarcy: 0.8561
# Total average test loss: 0.0076831339299678805
# Model Saved!
#
# Time elapsed: 1540.6964452266693
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4299425101367746
# Current batch average train loss: 0.014378931373357773
#
# Current batch: 100
# Current batch average train accuracy: 0.4367697688935684
# Current batch average train loss: 0.013995468616485596
#
# Current batch: 200
# Current batch average train accuracy: 0.5638825108753873
# Current batch average train loss: 0.012810117565095425
#
# Current batch: 300
# Current batch average train accuracy: 0.4334504984294516
# Current batch average train loss: 0.014349146746098995
#
# Total average train accuarcy: 0.6157012504890281
# Total average train loss: 0.011576731731891632
#
# [ Test epoch: 43 ]
#
# Total average test accuarcy: 0.8348
# Total average test loss: 0.007570461112260818
# Model Saved!
#
# Time elapsed: 1576.9765379428864
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6437168695446855
# Current batch average train loss: 0.01127303671091795
#
# Current batch: 100
# Current batch average train accuracy: 0.6864975019789269
# Current batch average train loss: 0.010906541720032692
#
# Current batch: 200
# Current batch average train accuracy: 0.41423376076197815
# Current batch average train loss: 0.014631090685725212
#
# Current batch: 300
# Current batch average train accuracy: 0.6888673072280447
# Current batch average train loss: 0.010561804287135601
#
# Total average train accuarcy: 0.6232341967328084
# Total average train loss: 0.011490900698900222
#
# [ Test epoch: 44 ]
#
# Total average test accuarcy: 0.8615
# Total average test loss: 0.007467877179384232
# Model Saved!
#
# Time elapsed: 1613.268168926239
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5938047065180949
# Current batch average train loss: 0.01250104047358036
#
# Current batch: 100
# Current batch average train accuracy: 0.5302961164328134
# Current batch average train loss: 0.013184635899960995
#
# Current batch: 200
# Current batch average train accuracy: 0.6396331066853909
# Current batch average train loss: 0.011708536185324192
#
# Current batch: 300
# Current batch average train accuracy: 0.616662781834802
# Current batch average train loss: 0.012193605303764343
#
# Total average train accuarcy: 0.619606025059651
# Total average train loss: 0.011545849772691727
#
# [ Test epoch: 45 ]
#
# Total average test accuarcy: 0.8438
# Total average test loss: 0.007633028316497803
# Model Saved!
#
# Time elapsed: 1649.3800854682922
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.42209611978679046
# Current batch average train loss: 0.014360349625349045
#
# Current batch: 100
# Current batch average train accuracy: 0.8220910271494447
# Current batch average train loss: 0.00774226151406765
#
# Current batch: 200
# Current batch average train accuracy: 0.5722895622932592
# Current batch average train loss: 0.012471409514546394
#
# Current batch: 300
# Current batch average train accuracy: 0.45724508327681423
# Current batch average train loss: 0.013934599235653877
#
# Total average train accuarcy: 0.6219042842346392
# Total average train loss: 0.011500987825393676
#
# [ Test epoch: 46 ]
#
# Total average test accuarcy: 0.8669
# Total average test loss: 0.007306944555044174
# Model Saved!
#
# Time elapsed: 1685.5367217063904
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7755263791105947
# Current batch average train loss: 0.008905388414859772
#
# Current batch: 100
# Current batch average train accuracy: 0.5081521244468389
# Current batch average train loss: 0.01339046098291874
#
# Current batch: 200
# Current batch average train accuracy: 0.4673643700488523
# Current batch average train loss: 0.013819996267557144
#
# Current batch: 300
# Current batch average train accuracy: 0.8081720439880363
# Current batch average train loss: 0.008351602591574192
#
# Total average train accuarcy: 0.6140131246369368
# Total average train loss: 0.011642774876356125
#
# [ Test epoch: 47 ]
#
# Total average test accuarcy: 0.8556
# Total average test loss: 0.007617387241125107
# Model Saved!
#
# Time elapsed: 1721.5759029388428
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4618699770085708
# Current batch average train loss: 0.013875158503651619
#
# Current batch: 100
# Current batch average train accuracy: 0.4611103344082287
# Current batch average train loss: 0.014074989594519138
#
# Current batch: 200
# Current batch average train accuracy: 0.826723346175938
# Current batch average train loss: 0.007360080257058144
#
# Current batch: 300
# Current batch average train accuracy: 0.7724194383878233
# Current batch average train loss: 0.008032661862671375
#
# Total average train accuarcy: 0.6210701204146742
# Total average train loss: 0.011550401883125306
#
# [ Test epoch: 48 ]
#
# Total average test accuarcy: 0.8625
# Total average test loss: 0.007495154547691345
# Model Saved!
#
# Time elapsed: 1757.3038432598114
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6000334170829489
# Current batch average train loss: 0.012499511241912842
#
# Current batch: 100
# Current batch average train accuracy: 0.7209556728751337
# Current batch average train loss: 0.01033080741763115
#
# Current batch: 200
# Current batch average train accuracy: 0.46625290736179303
# Current batch average train loss: 0.014241958037018776
#
# Current batch: 300
# Current batch average train accuracy: 0.6938236687209236
# Current batch average train loss: 0.010638656094670296
#
# Total average train accuarcy: 0.6220340285423785
# Total average train loss: 0.011521691279411316
#
# [ Test epoch: 49 ]
#
# Total average test accuarcy: 0.8623
# Total average test loss: 0.007219120556116104
# Model Saved!
#
# Time elapsed: 1793.3889818191528
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7060886726728292
# Current batch average train loss: 0.010639932006597519
#
# Current batch: 100
# Current batch average train accuracy: 0.4993793471251005
# Current batch average train loss: 0.01350198034197092
#
# Current batch: 200
# Current batch average train accuracy: 0.49004273100520407
# Current batch average train loss: 0.013521154411137104
#
# Current batch: 300
# Current batch average train accuracy: 0.4497540218829105
# Current batch average train loss: 0.013600658625364304
#
# Total average train accuarcy: 0.6538479066105415
# Total average train loss: 0.010974371136426925
#
# [ Test epoch: 50 ]
#
# Total average test accuarcy: 0.9238
# Total average test loss: 0.006519994908571243
# Model Saved!
#
# Time elapsed: 1829.403012752533
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6855162808855739
# Current batch average train loss: 0.011312181130051613
#
# Current batch: 100
# Current batch average train accuracy: 0.7410005306692328
# Current batch average train loss: 0.009731419384479523
#
# Current batch: 200
# Current batch average train accuracy: 0.8900487178263755
# Current batch average train loss: 0.006771711632609367
#
# Current batch: 300
# Current batch average train accuracy: 0.7778490384933925
# Current batch average train loss: 0.009303297847509384
#
# Total average train accuarcy: 0.6559058544650452
# Total average train loss: 0.010896759327650071
#
# [ Test epoch: 51 ]
#
# Total average test accuarcy: 0.9239
# Total average test loss: 0.006415260803699493
# Model Saved!
#
# Time elapsed: 1865.2164843082428
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7440707602983184
# Current batch average train loss: 0.01024731993675232
#
# Current batch: 100
# Current batch average train accuracy: 0.5921566233469859
# Current batch average train loss: 0.01221214048564434
#
# Current batch: 200
# Current batch average train accuracy: 0.914324969682982
# Current batch average train loss: 0.00582370487973094
#
# Current batch: 300
# Current batch average train accuracy: 0.8870232084445557
# Current batch average train loss: 0.006510624662041664
#
# Total average train accuarcy: 0.6701017966905837
# Total average train loss: 0.01069616590499878
#
# [ Test epoch: 52 ]
#
# Total average test accuarcy: 0.93
# Total average test loss: 0.006215775907039642
# Model Saved!
#
# Time elapsed: 1901.1592178344727
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8180380310806346
# Current batch average train loss: 0.007950611412525177
#
# Current batch: 100
# Current batch average train accuracy: 0.5103936897054671
# Current batch average train loss: 0.013009346090257168
#
# Current batch: 200
# Current batch average train accuracy: 0.476454542146272
# Current batch average train loss: 0.01318560540676117
#
# Current batch: 300
# Current batch average train accuracy: 0.7697564636701525
# Current batch average train loss: 0.009501749649643898
#
# Total average train accuarcy: 0.679255295103768
# Total average train loss: 0.010506217583417892
#
# [ Test epoch: 53 ]
#
# Total average test accuarcy: 0.9291
# Total average test loss: 0.006273045337200165
# Model Saved!
#
# Time elapsed: 1937.4043371677399
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7611572292328462
# Current batch average train loss: 0.009233118034899235
#
# Current batch: 100
# Current batch average train accuracy: 0.9370535408981701
# Current batch average train loss: 0.005751145537942648
#
# Current batch: 200
# Current batch average train accuracy: 0.8340422943064383
# Current batch average train loss: 0.008116086944937706
#
# Current batch: 300
# Current batch average train accuracy: 0.8888891998786946
# Current batch average train loss: 0.007295930292457342
#
# Total average train accuarcy: 0.6780941160823919
# Total average train loss: 0.010497604234218597
#
# [ Test epoch: 54 ]
#
# Total average test accuarcy: 0.9308
# Total average test loss: 0.006146200501918793
# Model Saved!
#
# Time elapsed: 1973.752375125885
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7836319012040672
# Current batch average train loss: 0.00930301658809185
#
# Current batch: 100
# Current batch average train accuracy: 0.8565029212003035
# Current batch average train loss: 0.00789010338485241
#
# Current batch: 200
# Current batch average train accuracy: 0.7602162268648851
# Current batch average train loss: 0.009622689336538315
#
# Current batch: 300
# Current batch average train accuracy: 0.4891140845957809
# Current batch average train loss: 0.012891124933958054
#
# Total average train accuarcy: 0.6702243970972636
# Total average train loss: 0.010663378496170044
#
# [ Test epoch: 55 ]
#
# Total average test accuarcy: 0.936
# Total average test loss: 0.006138998395204544
# Model Saved!
#
# Time elapsed: 2009.6457414627075
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8751502105423201
# Current batch average train loss: 0.007027769461274147
#
# Current batch: 100
# Current batch average train accuracy: 0.8507619137053481
# Current batch average train loss: 0.006889636628329754
#
# Current batch: 200
# Current batch average train accuracy: 0.5251951748920384
# Current batch average train loss: 0.013010310009121895
#
# Current batch: 300
# Current batch average train accuracy: 0.46544613495748055
# Current batch average train loss: 0.013206109404563904
#
# Total average train accuarcy: 0.6786202342053796
# Total average train loss: 0.010486569678783416
#
# [ Test epoch: 56 ]
#
# Total average test accuarcy: 0.9367
# Total average test loss: 0.00609983925819397
# Model Saved!
#
# Time elapsed: 2046.2241275310516
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7491516614013913
# Current batch average train loss: 0.009874232113361359
#
# Current batch: 100
# Current batch average train accuracy: 0.5521124126605401
# Current batch average train loss: 0.01265079528093338
#
# Current batch: 200
# Current batch average train accuracy: 0.5184868944670811
# Current batch average train loss: 0.012649406678974628
#
# Current batch: 300
# Current batch average train accuracy: 0.8450456828018221
# Current batch average train loss: 0.00770541001111269
#
# Total average train accuarcy: 0.6662768403600392
# Total average train loss: 0.010669617754220963
#
# [ Test epoch: 57 ]
#
# Total average test accuarcy: 0.93
# Total average test loss: 0.006455906426906586
# Model Saved!
#
# Time elapsed: 2082.0189201831818
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7760765710474168
# Current batch average train loss: 0.009246854111552238
#
# Current batch: 100
# Current batch average train accuracy: 0.5602471902929665
# Current batch average train loss: 0.012571717612445354
#
# Current batch: 200
# Current batch average train accuracy: 0.5582884744848982
# Current batch average train loss: 0.012044842354953289
#
# Current batch: 300
# Current batch average train accuracy: 0.5930718358868301
# Current batch average train loss: 0.01178634725511074
#
# Total average train accuarcy: 0.6874598246852321
# Total average train loss: 0.010356520009040833
#
# [ Test epoch: 58 ]
#
# Total average test accuarcy: 0.9391
# Total average test loss: 0.006000168335437775
# Model Saved!
#
# Time elapsed: 2117.9386270046234
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5773153977315809
# Current batch average train loss: 0.012278463691473007
#
# Current batch: 100
# Current batch average train accuracy: 0.6006643440097207
# Current batch average train loss: 0.011903725564479828
#
# Current batch: 200
# Current batch average train accuracy: 0.6415618840035953
# Current batch average train loss: 0.011367595754563808
#
# Current batch: 300
# Current batch average train accuracy: 0.519050043372939
# Current batch average train loss: 0.012875070795416832
#
# Total average train accuarcy: 0.6636619473920929
# Total average train loss: 0.010685809931755066
#
# [ Test epoch: 59 ]
#
# Total average test accuarcy: 0.9373
# Total average test loss: 0.006403863847255707
# Model Saved!
#
# Time elapsed: 2153.887545108795
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4789273806494766
# Current batch average train loss: 0.01272771880030632
#
# Current batch: 100
# Current batch average train accuracy: 0.6603225468850482
# Current batch average train loss: 0.011157559230923653
#
# Current batch: 200
# Current batch average train accuracy: 0.7914504271759984
# Current batch average train loss: 0.009109081700444221
#
# Current batch: 300
# ...
# Total average test loss: 0.005573206996917724
# Model Saved!
#
# Time elapsed: 4669.440574884415
#
# [ Train epoch: 130 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7600682775422403
# Current batch average train loss: 0.009759005159139633
#
# Current batch: 100
# Current batch average train accuracy: 0.8837273931605619
# Current batch average train loss: 0.007048032246530056
#
# Current batch: 200
# Current batch average train accuracy: 0.5583201313800343
# Current batch average train loss: 0.011927122250199318
#
# Current batch: 300
# Current batch average train accuracy: 0.5266775293050964
# Current batch average train loss: 0.012218918651342392
#
# Total average train accuarcy: 0.7149585725212613
# Total average train loss: 0.009720008643865585
#
# [ Test epoch: 130 ]
#
# Total average test accuarcy: 0.9618
# Total average test loss: 0.005573765295743942
# Model Saved!
#
# Time elapsed: 4706.103898525238
#
# [ Train epoch: 131 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8962616805258848
# Current batch average train loss: 0.007005162537097931
#
# Current batch: 100
# Current batch average train accuracy: 0.8187078147565301
# Current batch average train loss: 0.008451061323285103
#
# Current batch: 200
# Current batch average train accuracy: 0.7524194832167911
# Current batch average train loss: 0.009675923734903336
#
# Current batch: 300
# Current batch average train accuracy: 0.7073182210875112
# Current batch average train loss: 0.010617140680551529
#
# Total average train accuarcy: 0.707519104374514
# Total average train loss: 0.009807405976057053
#
# [ Test epoch: 131 ]
#
# Total average test accuarcy: 0.9614
# Total average test loss: 0.005987977397441864
# Model Saved!
#
# Time elapsed: 4741.210229873657
#
# [ Train epoch: 132 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5410959821574659
# Current batch average train loss: 0.012184124439954758
#
# Current batch: 100
# Current batch average train accuracy: 0.7983911390614045
# Current batch average train loss: 0.008643494918942451
#
# Current batch: 200
# Current batch average train accuracy: 0.5266919403138857
# Current batch average train loss: 0.011971784755587578
#
# Current batch: 300
# Current batch average train accuracy: 0.6811864521515552
# Current batch average train loss: 0.01061505451798439
#
# Total average train accuarcy: 0.7151108688178975
# Total average train loss: 0.009703673514127731
#
# [ Test epoch: 132 ]
#
# Total average test accuarcy: 0.9609
# Total average test loss: 0.0054675867080688475
# Model Saved!
#
# Time elapsed: 4775.999307155609
#
# [ Train epoch: 133 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5736812134547417
# Current batch average train loss: 0.011840078979730606
#
# Current batch: 100
# Current batch average train accuracy: 0.868023371301776
# Current batch average train loss: 0.007647229358553886
#
# Current batch: 200
# Current batch average train accuracy: 0.7320002408361519
# Current batch average train loss: 0.009894905611872673
#
# Current batch: 300
# Current batch average train accuracy: 0.8972303318025134
# Current batch average train loss: 0.006771673448383808
#
# Total average train accuarcy: 0.7172236031968109
# Total average train loss: 0.009699819957017899
#
# [ Test epoch: 133 ]
#
# Total average test accuarcy: 0.9613
# Total average test loss: 0.00556997926235199
# Model Saved!
#
# Time elapsed: 4810.662168502808
#
# [ Train epoch: 134 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8796248615252108
# Current batch average train loss: 0.007151224184781313
#
# Current batch: 100
# Current batch average train accuracy: 0.5023122899479094
# Current batch average train loss: 0.012482846155762672
#
# Current batch: 200
# Current batch average train accuracy: 0.9385409184913589
# Current batch average train loss: 0.005445011425763369
#
# Current batch: 300
# Current batch average train accuracy: 0.8314682267469823
# Current batch average train loss: 0.008129071444272995
#
# Total average train accuarcy: 0.7251358687760132
# Total average train loss: 0.009568432912826538
#
# [ Test epoch: 134 ]
#
# Total average test accuarcy: 0.96
# Total average test loss: 0.005547239768505096
# Model Saved!
#
# Time elapsed: 4846.224460840225
#
# [ Train epoch: 135 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7446383977372176
# Current batch average train loss: 0.009781126864254475
#
# Current batch: 100
# Current batch average train accuracy: 0.9776783585236534
# Current batch average train loss: 0.004899939056485891
#
# Current batch: 200
# Current batch average train accuracy: 0.5676800569729614
# Current batch average train loss: 0.011954627931118011
#
# Current batch: 300
# Current batch average train accuracy: 0.7043628795386808
# Current batch average train loss: 0.010240703821182251
#
# Total average train accuarcy: 0.7102353406905448
# Total average train loss: 0.009763081233501435
#
# [ Test epoch: 135 ]
#
# Total average test accuarcy: 0.9605
# Total average test loss: 0.005785269290208816
# Model Saved!
#
# Time elapsed: 4881.136205673218
#
# [ Train epoch: 136 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9225173077254892
# Current batch average train loss: 0.005843056831508875
#
# Current batch: 100
# Current batch average train accuracy: 0.6282622162146795
# Current batch average train loss: 0.011258067563176155
#
# Current batch: 200
# Current batch average train accuracy: 0.738828901310481
# Current batch average train loss: 0.009750574827194214
#
# Current batch: 300
# Current batch average train accuracy: 0.5392823109752088
# Current batch average train loss: 0.011944934725761414
#
# Total average train accuarcy: 0.7093495991050149
# Total average train loss: 0.00975593462228775
#
# [ Test epoch: 136 ]
#
# Total average test accuarcy: 0.9616
# Total average test loss: 0.005583851283788681
# Model Saved!
#
# Time elapsed: 4916.458729028702
#
# [ Train epoch: 137 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.566563273897824
# Current batch average train loss: 0.011559844017028809
#
# Current batch: 100
# Current batch average train accuracy: 0.9616189607416651
# Current batch average train loss: 0.005104656796902418
#
# Current batch: 200
# Current batch average train accuracy: 0.9035722289243605
# Current batch average train loss: 0.006653652526438236
#
# Current batch: 300
# Current batch average train accuracy: 0.5237466786786662
# Current batch average train loss: 0.012018552049994469
#
# Total average train accuarcy: 0.7123091817072446
# Total average train loss: 0.009726916894912719
#
# [ Test epoch: 137 ]
#
# Total average test accuarcy: 0.9613
# Total average test loss: 0.005506453967094422
# Model Saved!
#
# Time elapsed: 4951.577654600143
#
# [ Train epoch: 138 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7979430300754419
# Current batch average train loss: 0.008824322372674942
#
# Current batch: 100
# Current batch average train accuracy: 0.896699231753963
# Current batch average train loss: 0.0071589951403439045
#
# Current batch: 200
# Current batch average train accuracy: 0.6336658308170808
# Current batch average train loss: 0.011335420422255993
#
# Current batch: 300
# Current batch average train accuracy: 0.81851693066007
# Current batch average train loss: 0.008569004014134407
#
# Total average train accuarcy: 0.7117444676412734
# Total average train loss: 0.009734169529676437
#
# [ Test epoch: 138 ]
#
# Total average test accuarcy: 0.9599
# Total average test loss: 0.006060139906406402
# Model Saved!
#
# Time elapsed: 4986.534926891327
#
# [ Train epoch: 139 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7810387060995702
# Current batch average train loss: 0.009294513612985611
#
# Current batch: 100
# Current batch average train accuracy: 0.7941509632320419
# Current batch average train loss: 0.009164541959762573
#
# Current batch: 200
# Current batch average train accuracy: 0.8303534849223825
# Current batch average train loss: 0.008334781974554062
#
# Current batch: 300
# Current batch average train accuracy: 0.5880389764343247
# Current batch average train loss: 0.011391384527087212
#
# Total average train accuarcy: 0.7120443871464505
# Total average train loss: 0.009746530363559722
#
# [ Test epoch: 139 ]
#
# Total average test accuarcy: 0.9621
# Total average test loss: 0.005504730236530304
# Model Saved!
#
# Time elapsed: 5022.522376298904
#
# [ Train epoch: 140 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8531905923314845
# Current batch average train loss: 0.008044412359595299
#
# Current batch: 100
# Current batch average train accuracy: 0.6064075503773628
# Current batch average train loss: 0.011486947536468506
#
# Current batch: 200
# Current batch average train accuracy: 0.9230901880836339
# Current batch average train loss: 0.00589533057063818
#
# Current batch: 300
# Current batch average train accuracy: 0.5117250621641798
# Current batch average train loss: 0.012420861050486565
#
# Total average train accuarcy: 0.7160877471321178
# Total average train loss: 0.00968357735157013
#
# [ Test epoch: 140 ]
#
# Total average test accuarcy: 0.961
# Total average test loss: 0.005577146685123444
# Model Saved!
#
# Time elapsed: 5057.728877782822
#
# [ Train epoch: 141 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9612971985278465
# Current batch average train loss: 0.005089777056127787
#
# Current batch: 100
# Current batch average train accuracy: 0.6645540702736756
# Current batch average train loss: 0.010790137574076653
#
# Current batch: 200
# Current batch average train accuracy: 0.5066635632560018
# Current batch average train loss: 0.012493275105953217
#
# Current batch: 300
# Current batch average train accuracy: 0.7681957930754708
# Current batch average train loss: 0.009462188929319382
#
# Total average train accuarcy: 0.728221903083862
# Total average train loss: 0.00944678787112236
#
# [ Test epoch: 141 ]
#
# Total average test accuarcy: 0.9601
# Total average test loss: 0.005786312222480774
# Model Saved!
#
# Time elapsed: 5092.926735639572
#
# [ Train epoch: 142 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7637789850401049
# Current batch average train loss: 0.00918422918766737
#
# Current batch: 100
# Current batch average train accuracy: 0.8357003953897855
# Current batch average train loss: 0.008172053843736649
#
# Current batch: 200
# Current batch average train accuracy: 0.9512458338110904
# Current batch average train loss: 0.005572538822889328
#
# Current batch: 300
# Current batch average train accuracy: 0.7205772811081259
# Current batch average train loss: 0.010077541694045067
#
# Total average train accuarcy: 0.7145961348858226
# Total average train loss: 0.009665640321969987
#
# [ Test epoch: 142 ]
#
# Total average test accuarcy: 0.9594
# Total average test loss: 0.0055662357211112975
# Model Saved!
#
# Time elapsed: 5127.912845373154
#
# [ Train epoch: 143 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5156472921994535
# Current batch average train loss: 0.012196588329970837
#
# Current batch: 100
# Current batch average train accuracy: 0.8943778428031056
# Current batch average train loss: 0.006945441477000713
#
# Current batch: 200
# Current batch average train accuracy: 0.558652781876966
# Current batch average train loss: 0.011554671451449394
#
# Current batch: 300
# Current batch average train accuracy: 0.6510356613253346
# Current batch average train loss: 0.011196160688996315
#
# Total average train accuarcy: 0.706512744860671
# Total average train loss: 0.009804602615833283
#
# [ Test epoch: 143 ]
#
# Total average test accuarcy: 0.9602
# Total average test loss: 0.0056960383355617525
# Model Saved!
#
# Time elapsed: 5162.839333534241
#
# [ Train epoch: 144 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.47487579849336253
# Current batch average train loss: 0.012902183458209038
#
# Current batch: 100
# Current batch average train accuracy: 0.49307636942823285
# Current batch average train loss: 0.01264473982155323
#
# Current batch: 200
# Current batch average train accuracy: 0.5518028070031955
# Current batch average train loss: 0.01212131604552269
#
# Current batch: 300
# Current batch average train accuracy: 0.5404958848373342
# Current batch average train loss: 0.012191081419587135
#
# Total average train accuarcy: 0.7133897932964527
# Total average train loss: 0.00969018879532814
#
# [ Test epoch: 144 ]
#
# Total average test accuarcy: 0.9604
# Total average test loss: 0.005683418744802475
# Model Saved!
#
# Time elapsed: 5198.2450387477875
#
# [ Train epoch: 145 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9433861897665595
# Current batch average train loss: 0.005295007489621639
#
# Current batch: 100
# Current batch average train accuracy: 0.8217677899489874
# Current batch average train loss: 0.008274586871266365
#
# Current batch: 200
# Current batch average train accuracy: 0.9076223606653292
# Current batch average train loss: 0.006889197044074535
#
# Current batch: 300
# Current batch average train accuracy: 0.8407210994270371
# Current batch average train loss: 0.008207577280700207
#
# Total average train accuarcy: 0.7135043715446263
# Total average train loss: 0.00973720272064209
#
# [ Test epoch: 145 ]
#
# Total average test accuarcy: 0.9619
# Total average test loss: 0.005698410815000534
# Model Saved!
#
# Time elapsed: 5233.56747674942
#
# [ Train epoch: 146 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5817268259872997
# Current batch average train loss: 0.011789406649768353
#
# Current batch: 100
# Current batch average train accuracy: 0.6329079069392891
# Current batch average train loss: 0.011057401075959206
#
# Current batch: 200
# Current batch average train accuracy: 0.9230264246703298
# Current batch average train loss: 0.006464353762567043
#
# Current batch: 300
# Current batch average train accuracy: 0.8689847753133004
# Current batch average train loss: 0.007783827837556601
#
# Total average train accuarcy: 0.7059943272852924
# Total average train loss: 0.009783151551485061
#
# [ Test epoch: 146 ]
#
# Total average test accuarcy: 0.9608
# Total average test loss: 0.00570985723733902
# Model Saved!
#
# Time elapsed: 5268.633794784546
#
# [ Train epoch: 147 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9814656254422379
# Current batch average train loss: 0.004697650205343962
#
# Current batch: 100
# Current batch average train accuracy: 0.6590313374055181
# Current batch average train loss: 0.011065959930419922
#
# Current batch: 200
# Current batch average train accuracy: 0.8278253119208818
# Current batch average train loss: 0.008314413949847221
#
# Current batch: 300
# Current batch average train accuracy: 0.6203797764705048
# Current batch average train loss: 0.011082708835601807
#
# Total average train accuarcy: 0.716983901940763
# Total average train loss: 0.009640652004480362
#
# [ Test epoch: 147 ]
#
# Total average test accuarcy: 0.9604
# Total average test loss: 0.00567877054810524
# Model Saved!
#
# Time elapsed: 5303.064214468002
#
# [ Train epoch: 148 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5360798383978134
# Current batch average train loss: 0.011807119473814964
#
# Current batch: 100
# Current batch average train accuracy: 0.8904264940761208
# Current batch average train loss: 0.0071286391466856
#
# Current batch: 200
# Current batch average train accuracy: 0.7795623274665784
# Current batch average train loss: 0.008893962018191814
#
# Current batch: 300
# Current batch average train accuracy: 0.8328350757057285
# Current batch average train loss: 0.008206984028220177
#
# Total average train accuarcy: 0.7152344109258293
# Total average train loss: 0.009661819124221802
#
# [ Test epoch: 148 ]
#
# Total average test accuarcy: 0.9613
# Total average test loss: 0.005619683736562729
# Model Saved!
#
# Time elapsed: 5338.10554766655
#
# [ Train epoch: 149 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5918741634771294
# Current batch average train loss: 0.011383949778974056
#
# Current batch: 100
# Current batch average train accuracy: 0.9641161322764508
# Current batch average train loss: 0.005097524728626013
#
# Current batch: 200
# Current batch average train accuracy: 0.7847963538238915
# Current batch average train loss: 0.008872492238879204
#
# Current batch: 300
# Current batch average train accuracy: 0.9677128944682417
# Current batch average train loss: 0.005055767018347979
#
# Total average train accuarcy: 0.7157913127919805
# Total average train loss: 0.00966780280470848
#
# [ Test epoch: 149 ]
#
# Total average test accuarcy: 0.961
# Total average test loss: 0.005720601707696915
# Model Saved!
#
# Time elapsed: 5372.803451061249

# %% [markdown]
# ## Best accuracy - 96.16%
# ## training time(1 epoch) - 34 second
