# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import os
import torch.nn.functional as F

# %% [markdown]
# ## Resnet 18

# %%
class BasicBlock(nn.Module):
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()

    self.conv1 = nn.Conv2d(in_planes, planes, 3, stride, 1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    
    self.conv2 = nn.Conv2d(planes, planes, 3, 1, 1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()

    if stride != 1:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, planes, 1, stride, bias=False),
          nn.BatchNorm2d(planes),
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out


class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    
    self.in_planes = 64
    self.conv1 = nn.Conv2d(3, 64, 3, 1, 1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], 1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], 2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], 2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], 2)
    self.adapPool = nn.AdaptiveAvgPool2d(1)
    self.linear = nn.Linear(512, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1] * (num_blocks - 1)  # 첫 블럭의 stride만 2 혹은 1 나머지 반복은 1
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = self.adapPool(out)
    out = out.view(x.shape[0], -1)
    return self.linear(out)
    

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader

train_transform = transforms.Compose(
    [
     transforms.RandomCrop(32, padding=4),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
    ]
)

test_transform = transforms.Compose(
    [
     transforms.ToTensor(),
    ]
)

train_dataset = CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_dataset = CIFAR10(root='./data', train=False, download=True, transform=test_transform)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Define mixup, label smoothing

# %%
import numpy as np
import pdb

mixup_alpha = 1.0

def mixup_data(x, y):
  lam = np.random.rand()  # 0~1
  batch_size = x.shape[0]
  index = torch.randperm(batch_size).to(device)  # randperm: batch_size 개수만큼 unique random index를 가진 1차원 tensor
  mixed_x = lam * x + (1-lam) * x[index]
  y_a, y_b = y, y[index]
  return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
  return lam * criterion(pred, y_a) + (1-lam) * criterion(pred, y_b)

class LabelSmoothingCrossEntropy(nn.Module):
  def __init__(self):
    super(LabelSmoothingCrossEntropy, self).__init__()

  def forward(self, y, targets, smoothing=0.1):
    confidence = 1. - smoothing
    log_probs = F.log_softmax(y, dim=-1)  # 0에 가까워야 좋음 (loss down)
    true_probs = torch.zeros_like(log_probs)
    true_probs.fill_(smoothing / (y.shape[1] - 1))  # 일단 10개의 라벨 전부 0.1111 로 채움
    true_probs.scatter_(1, targets.data.unsqueeze(1), confidence)  # 각 배치별로 정답의 인덱스값을 0.1111 에서 0.9로 채워줌  # torch.scatter_(dim, index, src)
    return torch.mean(torch.sum(true_probs * -log_probs, dim=-1))

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet18_cifar10.pth'

criterion = LabelSmoothingCrossEntropy()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets)
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = (lam * predicted.eq(targets_a).sum().item() + (1 - lam) * predicted.eq(targets_b).sum().item())
        correct += current_correct

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %%
import time


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr /= 10
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

for epoch in range(0, 150):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.08477877211326222
# Current batch average train loss: 0.01844143308699131
#
# Current batch: 100
# Current batch average train accuracy: 0.17244588517472237
# Current batch average train loss: 0.01778549887239933
#
# Current batch: 200
# Current batch average train accuracy: 0.1378255725844678
# Current batch average train loss: 0.01752232387661934
#
# Current batch: 300
# Current batch average train accuracy: 0.230640408061667
# Current batch average train loss: 0.016410542652010918
#
# Total average train accuarcy: 0.1798408060593202
# Total average train loss: 0.018602374048233034
#
# [ Test epoch: 0 ]
#
# Total average test accuarcy: 0.3042
# Total average test loss: 0.015726638066768647
# Model Saved!
#
# Time elapsed: 67.60855865478516
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.22014992677417644
# Current batch average train loss: 0.01708904094994068
#
# Current batch: 100
# Current batch average train accuracy: 0.2796834445188075
# Current batch average train loss: 0.01624532788991928
#
# Current batch: 200
# Current batch average train accuracy: 0.31745279913251667
# Current batch average train loss: 0.01605561003088951
#
# Current batch: 300
# Current batch average train accuracy: 0.27058623922979075
# Current batch average train loss: 0.016554292291402817
#
# Total average train accuarcy: 0.27945877980051015
# Total average train loss: 0.016063131573200225
#
# [ Test epoch: 1 ]
#
# Total average test accuarcy: 0.3317
# Total average test loss: 0.01553235672712326
# Model Saved!
#
# Time elapsed: 135.27540278434753
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.37492237058701283
# Current batch average train loss: 0.014224560931324959
#
# Current batch: 100
# Current batch average train accuracy: 0.3775376314004403
# Current batch average train loss: 0.015008428134024143
#
# Current batch: 200
# Current batch average train accuracy: 0.42155702951417595
# Current batch average train loss: 0.01443646289408207
#
# Current batch: 300
# Current batch average train accuracy: 0.31274142290301093
# Current batch average train loss: 0.015472423285245895
#
# Total average train accuarcy: 0.33111385237760643
# Total average train loss: 0.015411258931159973
#
# [ Test epoch: 2 ]
#
# Total average test accuarcy: 0.3973
# Total average test loss: 0.01437486047744751
# Model Saved!
#
# Time elapsed: 203.5132818222046
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.2996219898128897
# Current batch average train loss: 0.015726344659924507
#
# Current batch: 100
# Current batch average train accuracy: 0.2763680353549696
# Current batch average train loss: 0.01630488969385624
#
# Current batch: 200
# Current batch average train accuracy: 0.4664542834201396
# Current batch average train loss: 0.013212128542363644
#
# Current batch: 300
# Current batch average train accuracy: 0.5000736799270727
# Current batch average train loss: 0.01378697156906128
#
# Total average train accuarcy: 0.37343972143210236
# Total average train loss: 0.014913967440128326
#
# [ Test epoch: 3 ]
#
# Total average test accuarcy: 0.3791
# Total average test loss: 0.014981303453445435
# Model Saved!
#
# Time elapsed: 271.88682770729065
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5610655232165016
# Current batch average train loss: 0.011873059906065464
#
# Current batch: 100
# Current batch average train accuracy: 0.3606855226844763
# Current batch average train loss: 0.015332711860537529
#
# Current batch: 200
# Current batch average train accuracy: 0.3070106872841274
# Current batch average train loss: 0.015777993947267532
#
# Current batch: 300
# Current batch average train accuracy: 0.3973509751007783
# Current batch average train loss: 0.014931855723261833
#
# Total average train accuarcy: 0.4105743874624371
# Total average train loss: 0.014452192649841308
#
# [ Test epoch: 4 ]
#
# Total average test accuarcy: 0.4224
# Total average test loss: 0.01411230001449585
# Model Saved!
#
# Time elapsed: 340.46753883361816
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.331821949602669
# Current batch average train loss: 0.015526151284575462
#
# Current batch: 100
# Current batch average train accuracy: 0.42173938781566866
# Current batch average train loss: 0.014810190536081791
#
# Current batch: 200
# Current batch average train accuracy: 0.47615541836723996
# Current batch average train loss: 0.013955961912870407
#
# Current batch: 300
# Current batch average train accuracy: 0.4956815816637388
# Current batch average train loss: 0.01334395632147789
#
# Total average train accuarcy: 0.45022305612798613
# Total average train loss: 0.013947133350372315
#
# [ Test epoch: 5 ]
#
# Total average test accuarcy: 0.5286
# Total average test loss: 0.012400508880615235
# Model Saved!
#
# Time elapsed: 408.78555703163147
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4768655751743827
# Current batch average train loss: 0.013134549371898174
#
# Current batch: 100
# Current batch average train accuracy: 0.34633720414277025
# Current batch average train loss: 0.01508491300046444
#
# Current batch: 200
# Current batch average train accuracy: 0.5575033090550855
# Current batch average train loss: 0.012602901086211205
#
# Current batch: 300
# Current batch average train accuracy: 0.38253391982662804
# Current batch average train loss: 0.015145454555749893
#
# Total average train accuarcy: 0.4754406161568922
# Total average train loss: 0.013564808945655822
#
# [ Test epoch: 6 ]
#
# Total average test accuarcy: 0.5039
# Total average test loss: 0.012844656729698182
# Model Saved!
#
# Time elapsed: 477.14438033103943
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7054049969727393
# Current batch average train loss: 0.01041074376553297
#
# Current batch: 100
# Current batch average train accuracy: 0.46987347253219064
# Current batch average train loss: 0.013486290350556374
#
# Current batch: 200
# Current batch average train accuracy: 0.44975054465495684
# Current batch average train loss: 0.0142204649746418
#
# Current batch: 300
# Current batch average train accuracy: 0.3725136164774913
# Current batch average train loss: 0.015051767230033875
#
# Total average train accuarcy: 0.5092972755387529
# Total average train loss: 0.013106963706016541
#
# [ Test epoch: 7 ]
#
# Total average test accuarcy: 0.5857
# Total average test loss: 0.011541671562194824
# Model Saved!
#
# Time elapsed: 545.8872170448303
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5516040798249734
# Current batch average train loss: 0.013194466009736061
#
# Current batch: 100
# Current batch average train accuracy: 0.3924654545134231
# Current batch average train loss: 0.014735838398337364
#
# Current batch: 200
# Current batch average train accuracy: 0.47172380101740674
# Current batch average train loss: 0.014443153515458107
#
# Current batch: 300
# Current batch average train accuracy: 0.41774588803541834
# Current batch average train loss: 0.015002282336354256
#
# Total average train accuarcy: 0.5375048887132106
# Total average train loss: 0.01275150548696518
#
# [ Test epoch: 8 ]
#
# Total average test accuarcy: 0.697
# Total average test loss: 0.009896296286582947
# Model Saved!
#
# Time elapsed: 614.3014333248138
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.3679091341749404
# Current batch average train loss: 0.01490580104291439
#
# Current batch: 100
# Current batch average train accuracy: 0.4065347593285851
# Current batch average train loss: 0.014211469329893589
#
# Current batch: 200
# Current batch average train accuracy: 0.6166581792059289
# Current batch average train loss: 0.011589936912059784
#
# Current batch: 300
# Current batch average train accuracy: 0.4280685839780337
# Current batch average train loss: 0.01433873362839222
#
# Total average train accuarcy: 0.5432131922246375
# Total average train loss: 0.012676226575374603
#
# [ Test epoch: 9 ]
#
# Total average test accuarcy: 0.5427
# Total average test loss: 0.011929908013343812
# Model Saved!
#
# Time elapsed: 682.7668652534485
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4306134613392649
# Current batch average train loss: 0.013951942324638367
#
# Current batch: 100
# Current batch average train accuracy: 0.4468787635427869
# Current batch average train loss: 0.01389315165579319
#
# Current batch: 200
# Current batch average train accuracy: 0.5852464276209269
# Current batch average train loss: 0.012516939081251621
#
# Current batch: 300
# Current batch average train accuracy: 0.3983028203793183
# Current batch average train loss: 0.014281041920185089
#
# Total average train accuarcy: 0.5597443399026445
# Total average train loss: 0.012393144998550414
#
# [ Test epoch: 10 ]
#
# Total average test accuarcy: 0.6031
# Total average test loss: 0.011453077924251556
# Model Saved!
#
# Time elapsed: 751.5013480186462
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.38558972285367077
# Current batch average train loss: 0.014656979590654373
#
# Current batch: 100
# Current batch average train accuracy: 0.7646409786421148
# Current batch average train loss: 0.009335001930594444
#
# Current batch: 200
# Current batch average train accuracy: 0.7206971548672875
# Current batch average train loss: 0.010059332475066185
#
# Current batch: 300
# Current batch average train accuracy: 0.628679338754895
# Current batch average train loss: 0.011862012557685375
#
# Total average train accuarcy: 0.5800767668341643
# Total average train loss: 0.012126742604970932
#
# [ Test epoch: 11 ]
#
# Total average test accuarcy: 0.7059
# Total average test loss: 0.009699210059642792
# Model Saved!
#
# Time elapsed: 819.7923600673676
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4828213006199853
# Current batch average train loss: 0.013688841834664345
#
# Current batch: 100
# Current batch average train accuracy: 0.7098643120861764
# Current batch average train loss: 0.01013882365077734
#
# Current batch: 200
# Current batch average train accuracy: 0.7428201051110082
# Current batch average train loss: 0.008844397030770779
#
# Current batch: 300
# Current batch average train accuracy: 0.6073123785655259
# Current batch average train loss: 0.01163179986178875
#
# Total average train accuarcy: 0.5977733921029311
# Total average train loss: 0.011839530069828033
#
# [ Test epoch: 12 ]
#
# Total average test accuarcy: 0.7474
# Total average test loss: 0.009172813975811005
# Model Saved!
#
# Time elapsed: 888.3967700004578
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5965151140291337
# Current batch average train loss: 0.01229880191385746
#
# Current batch: 100
# Current batch average train accuracy: 0.5701638620820259
# Current batch average train loss: 0.012262916192412376
#
# Current batch: 200
# Current batch average train accuracy: 0.43755664212087586
# Current batch average train loss: 0.014220179989933968
#
# Current batch: 300
# Current batch average train accuracy: 0.37353419651602626
# Current batch average train loss: 0.014723376370966434
#
# Total average train accuarcy: 0.6072368453579956
# Total average train loss: 0.011707716448307037
#
# [ Test epoch: 13 ]
#
# Total average test accuarcy: 0.7464
# Total average test loss: 0.009152519929409027
# Model Saved!
#
# Time elapsed: 956.8137664794922
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4380923263664177
# Current batch average train loss: 0.013823982328176498
#
# Current batch: 100
# Current batch average train accuracy: 0.7075334699512905
# Current batch average train loss: 0.010094214230775833
#
# Current batch: 200
# Current batch average train accuracy: 0.8248241883621201
# Current batch average train loss: 0.008261224254965782
#
# Current batch: 300
# Current batch average train accuracy: 0.6604819524508057
# Current batch average train loss: 0.011180654168128967
#
# Total average train accuarcy: 0.6035951856636211
# Total average train loss: 0.011745576821565629
#
# [ Test epoch: 14 ]
#
# Total average test accuarcy: 0.8162
# Total average test loss: 0.008258993536233902
# Model Saved!
#
# Time elapsed: 1025.2751388549805
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.527971936343134
# Current batch average train loss: 0.013228129595518112
#
# Current batch: 100
# Current batch average train accuracy: 0.7531188367300904
# Current batch average train loss: 0.009934410452842712
#
# Current batch: 200
# Current batch average train accuracy: 0.6326141214549347
# Current batch average train loss: 0.012059696950018406
#
# Current batch: 300
# Current batch average train accuracy: 0.4740412537822116
# Current batch average train loss: 0.013854142278432846
#
# Total average train accuarcy: 0.6061474126198
# Total average train loss: 0.011706650836467743
#
# [ Test epoch: 15 ]
#
# Total average test accuarcy: 0.8181
# Total average test loss: 0.008060553145408631
# Model Saved!
#
# Time elapsed: 1093.8789222240448
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8097180157045214
# Current batch average train loss: 0.008694451302289963
#
# Current batch: 100
# Current batch average train accuracy: 0.6941433689526643
# Current batch average train loss: 0.009959804825484753
#
# Current batch: 200
# Current batch average train accuracy: 0.4839148610123348
# Current batch average train loss: 0.01340750977396965
#
# Current batch: 300
# Current batch average train accuracy: 0.7880072071128601
# Current batch average train loss: 0.009111323393881321
#
# Total average train accuarcy: 0.6212620942658327
# Total average train loss: 0.011465866564512253
#
# [ Test epoch: 16 ]
#
# Total average test accuarcy: 0.8215
# Total average test loss: 0.007860167986154557
# Model Saved!
#
# Time elapsed: 1162.492415189743
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6245006647017817
# Current batch average train loss: 0.012000377289950848
#
# Current batch: 100
# Current batch average train accuracy: 0.5086879219480509
# Current batch average train loss: 0.012940846383571625
#
# Current batch: 200
# Current batch average train accuracy: 0.8062443152666338
# Current batch average train loss: 0.008652464486658573
#
# Current batch: 300
# Current batch average train accuracy: 0.7897380098767195
# Current batch average train loss: 0.008536289446055889
#
# Total average train accuarcy: 0.6160017445352288
# Total average train loss: 0.011547902215719223
#
# [ Test epoch: 17 ]
#
# Total average test accuarcy: 0.8167
# Total average test loss: 0.008159848552942276
# Model Saved!
#
# Time elapsed: 1231.0270054340363
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6665924088031616
# Current batch average train loss: 0.011348171159625053
#
# Current batch: 100
# Current batch average train accuracy: 0.45152199896914674
# Current batch average train loss: 0.013395166024565697
#
# Current batch: 200
# Current batch average train accuracy: 0.4297557069985908
# Current batch average train loss: 0.013612830080091953
#
# Current batch: 300
# Current batch average train accuracy: 0.45749860437647083
# Current batch average train loss: 0.013692660257220268
#
# Total average train accuarcy: 0.615947084919916
# Total average train loss: 0.01149212375640869
#
# [ Test epoch: 18 ]
#
# Total average test accuarcy: 0.8063
# Total average test loss: 0.008164278733730317
# Model Saved!
#
# Time elapsed: 1299.3202185630798
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5518058789501579
# Current batch average train loss: 0.012530157342553139
#
# Current batch: 100
# Current batch average train accuracy: 0.5707801723064139
# Current batch average train loss: 0.012570196762681007
#
# Current batch: 200
# Current batch average train accuracy: 0.64437186849775
# Current batch average train loss: 0.011392858810722828
#
# Current batch: 300
# Current batch average train accuracy: 0.7667480075961304
# Current batch average train loss: 0.009600277058780193
#
# Total average train accuarcy: 0.6454945582978759
# Total average train loss: 0.011101989005804062
#
# [ Test epoch: 19 ]
#
# Total average test accuarcy: 0.8032
# Total average test loss: 0.008207959878444672
# Model Saved!
#
# Time elapsed: 1367.7696113586426
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8721041709420874
# Current batch average train loss: 0.006903348956257105
#
# Current batch: 100
# Current batch average train accuracy: 0.48424257950355026
# Current batch average train loss: 0.013363885693252087
#
# Current batch: 200
# Current batch average train accuracy: 0.593793321650777
# Current batch average train loss: 0.011936280876398087
#
# Current batch: 300
# Current batch average train accuracy: 0.46543065854037147
# Current batch average train loss: 0.013497427105903625
#
# Total average train accuarcy: 0.6448258550633493
# Total average train loss: 0.011102904156446457
#
# [ Test epoch: 20 ]
#
# Total average test accuarcy: 0.7766
# Total average test loss: 0.008545435684919358
# Model Saved!
#
# Time elapsed: 1436.0287199020386
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.47730349969541663
# Current batch average train loss: 0.013630456291139126
#
# Current batch: 100
# Current batch average train accuracy: 0.7709687943272706
# Current batch average train loss: 0.009374672546982765
#
# Current batch: 200
# Current batch average train accuracy: 0.48136731866890037
# Current batch average train loss: 0.013470794074237347
#
# Current batch: 300
# Current batch average train accuracy: 0.6792614578267118
# Current batch average train loss: 0.010769698768854141
#
# Total average train accuarcy: 0.634475091768402
# Total average train loss: 0.011227193071842194
#
# [ Test epoch: 21 ]
#
# Total average test accuarcy: 0.8343
# Total average test loss: 0.007842323338985444
# Model Saved!
#
# Time elapsed: 1504.3449161052704
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5092672829199715
# Current batch average train loss: 0.012935011647641659
#
# Current batch: 100
# Current batch average train accuracy: 0.48967616050459234
# Current batch average train loss: 0.013474224135279655
#
# Current batch: 200
# Current batch average train accuracy: 0.631829513770106
# Current batch average train loss: 0.011918243020772934
#
# Current batch: 300
# Current batch average train accuracy: 0.6027191824518927
# Current batch average train loss: 0.012062501162290573
#
# Total average train accuarcy: 0.6512303907134945
# Total average train loss: 0.010968273404836654
#
# [ Test epoch: 22 ]
#
# Total average test accuarcy: 0.8269
# Total average test loss: 0.007872447526454926
# Model Saved!
#
# Time elapsed: 1572.370045185089
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8286225689802973
# Current batch average train loss: 0.007746363990008831
#
# Current batch: 100
# Current batch average train accuracy: 0.6975948839281665
# Current batch average train loss: 0.01072236429899931
#
# Current batch: 200
# Current batch average train accuracy: 0.8061151094960171
# Current batch average train loss: 0.008746863342821598
#
# Current batch: 300
# Current batch average train accuracy: 0.4767106552823121
# Current batch average train loss: 0.013453447259962559
#
# Total average train accuarcy: 0.6409718935953448
# Total average train loss: 0.01114407019853592
#
# [ Test epoch: 23 ]
#
# Total average test accuarcy: 0.8476
# Total average test loss: 0.007593784898519516
# Model Saved!
#
# Time elapsed: 1640.8027129173279
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7404055405252195
# Current batch average train loss: 0.010151746682822704
#
# Current batch: 100
# Current batch average train accuracy: 0.6466957008430677
# Current batch average train loss: 0.011264418251812458
#
# Current batch: 200
# Current batch average train accuracy: 0.4945157545988397
# Current batch average train loss: 0.013213399797677994
#
# Current batch: 300
# Current batch average train accuracy: 0.8993541899589916
# Current batch average train loss: 0.006401233375072479
#
# Total average train accuarcy: 0.6557847204670827
# Total average train loss: 0.01090884935259819
#
# [ Test epoch: 24 ]
#
# Total average test accuarcy: 0.8165
# Total average test loss: 0.007918857342004777
# Model Saved!
#
# Time elapsed: 1709.2632026672363
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8702667219899294
# Current batch average train loss: 0.006670465227216482
#
# Current batch: 100
# Current batch average train accuracy: 0.872787910036093
# Current batch average train loss: 0.007273215334862471
#
# Current batch: 200
# Current batch average train accuracy: 0.4668585766995295
# Current batch average train loss: 0.013676313683390617
#
# Current batch: 300
# Current batch average train accuracy: 0.8235151960664113
# Current batch average train loss: 0.008282450959086418
#
# Total average train accuarcy: 0.6489917520576126
# Total average train loss: 0.011022956395149231
#
# [ Test epoch: 25 ]
#
# Total average test accuarcy: 0.8532
# Total average test loss: 0.007285443437099456
# Model Saved!
#
# Time elapsed: 1777.5164685249329
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4813723618835239
# Current batch average train loss: 0.012993711978197098
#
# Current batch: 100
# Current batch average train accuracy: 0.5415630381777585
# Current batch average train loss: 0.013116460293531418
#
# Current batch: 200
# Current batch average train accuracy: 0.8125969992568547
# Current batch average train loss: 0.008641785942018032
#
# Current batch: 300
# Current batch average train accuracy: 0.45964578298129666
# Current batch average train loss: 0.013627763837575912
#
# Total average train accuarcy: 0.6480988358803522
# Total average train loss: 0.010979456117153168
#
# [ Test epoch: 26 ]
#
# Total average test accuarcy: 0.8563
# Total average test loss: 0.007271414369344711
# Model Saved!
#
# Time elapsed: 1845.6617922782898
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9214644198765909
# Current batch average train loss: 0.006262548733502626
#
# Current batch: 100
# Current batch average train accuracy: 0.7228928627208144
# Current batch average train loss: 0.009900035336613655
#
# Current batch: 200
# Current batch average train accuracy: 0.437851300311807
# Current batch average train loss: 0.013820331543684006
#
# Current batch: 300
# Current batch average train accuracy: 0.9026790670270338
# Current batch average train loss: 0.0067464858293533325
#
# Total average train accuarcy: 0.6524264306422992
# Total average train loss: 0.010955305675268173
#
# [ Test epoch: 27 ]
#
# Total average test accuarcy: 0.8262
# Total average test loss: 0.007868825167417525
# Model Saved!
#
# Time elapsed: 1913.9771628379822
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.49577081170120824
# Current batch average train loss: 0.013145210221409798
#
# Current batch: 100
# Current batch average train accuracy: 0.8597982086293146
# Current batch average train loss: 0.007133002392947674
#
# Current batch: 200
# Current batch average train accuracy: 0.7374710830694106
# Current batch average train loss: 0.010356721468269825
#
# Current batch: 300
# Current batch average train accuracy: 0.4961163093849532
# Current batch average train loss: 0.012988630682229996
#
# Total average train accuarcy: 0.6619877031656195
# Total average train loss: 0.010828961461782456
#
# [ Test epoch: 28 ]
#
# Total average test accuarcy: 0.8516
# Total average test loss: 0.007559547537565232
# Model Saved!
#
# Time elapsed: 1982.2739520072937
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4008407808901122
# Current batch average train loss: 0.014007464982569218
#
# Current batch: 100
# Current batch average train accuracy: 0.88670152402147
# Current batch average train loss: 0.007069552782922983
#
# Current batch: 200
# Current batch average train accuracy: 0.4758511317514018
# Current batch average train loss: 0.013390202075242996
#
# Current batch: 300
# Current batch average train accuracy: 0.8668569487362974
# Current batch average train loss: 0.006822237744927406
#
# Total average train accuarcy: 0.6704593322878424
# Total average train loss: 0.010638872110843658
#
# [ Test epoch: 29 ]
#
# Total average test accuarcy: 0.8635
# Total average test loss: 0.0073463371932506565
# Model Saved!
#
# Time elapsed: 2050.6189415454865
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6650825104242246
# Current batch average train loss: 0.01115775853395462
#
# Current batch: 100
# Current batch average train accuracy: 0.48352297904009534
# Current batch average train loss: 0.013219673186540604
#
# Current batch: 200
# Current batch average train accuracy: 0.5407215429923201
# Current batch average train loss: 0.012864350341260433
#
# Current batch: 300
# Current batch average train accuracy: 0.8300800141403126
# Current batch average train loss: 0.007999332621693611
#
# Total average train accuarcy: 0.6658688996489033
# Total average train loss: 0.010737629066705704
#
# [ Test epoch: 30 ]
#
# Total average test accuarcy: 0.8617
# Total average test loss: 0.00762034125328064
# Model Saved!
#
# Time elapsed: 2118.886120080948
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6687089182959427
# Current batch average train loss: 0.01081465557217598
#
# Current batch: 100
# Current batch average train accuracy: 0.5884397948898974
# Current batch average train loss: 0.012148731388151646
#
# Current batch: 200
# Current batch average train accuracy: 0.4887657124671272
# Current batch average train loss: 0.013077426701784134
#
# Current batch: 300
# Current batch average train accuracy: 0.47127978389155095
# Current batch average train loss: 0.013238916173577309
#
# Total average train accuarcy: 0.6607427655662331
# Total average train loss: 0.010813909730911255
#
# [ Test epoch: 31 ]
#
# Total average test accuarcy: 0.8578
# Total average test loss: 0.007677228599786759
# Model Saved!
#
# Time elapsed: 2187.0211148262024
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5631463959073619
# Current batch average train loss: 0.012389285489916801
#
# Current batch: 100
# Current batch average train accuracy: 0.9365249377121997
# Current batch average train loss: 0.00585060054436326
#
# Current batch: 200
# Current batch average train accuracy: 0.672517938187553
# Current batch average train loss: 0.011203117668628693
#
# Current batch: 300
# Current batch average train accuracy: 0.821014111261132
# Current batch average train loss: 0.008391674607992172
#
# Total average train accuarcy: 0.6601282950669275
# Total average train loss: 0.010779092018604278
#
# [ Test epoch: 32 ]
#
# Total average test accuarcy: 0.8455
# Total average test loss: 0.007823776584863662
# Model Saved!
#
# Time elapsed: 2255.3280692100525
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6187506883755021
# Current batch average train loss: 0.011818384751677513
#
# Current batch: 100
# Current batch average train accuracy: 0.48098472129093955
# Current batch average train loss: 0.01339725125581026
#
# Current batch: 200
# Current batch average train accuracy: 0.7164769874528514
# Current batch average train loss: 0.010234946385025978
#
# Current batch: 300
# Current batch average train accuracy: 0.8691898607646217
# Current batch average train loss: 0.006984347943216562
#
# Total average train accuarcy: 0.6593439396848694
# Total average train loss: 0.010846434757709503
#
# [ Test epoch: 33 ]
#
# Total average test accuarcy: 0.8611
# Total average test loss: 0.007288917571306229
# Model Saved!
#
# Time elapsed: 2323.4989171028137
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.46046628469254836
# Current batch average train loss: 0.013185778632760048
#
# Current batch: 100
# Current batch average train accuracy: 0.5085882815800756
# Current batch average train loss: 0.01295393519103527
#
# Current batch: 200
# Current batch average train accuracy: 0.9100753142511416
# Current batch average train loss: 0.005933576263487339
#
# Current batch: 300
# Current batch average train accuracy: 0.6298739866240096
# Current batch average train loss: 0.012148136273026466
#
# Total average train accuarcy: 0.6771270327377823
# Total average train loss: 0.010533971662521362
#
# [ Test epoch: 34 ]
#
# Total average test accuarcy: 0.8266
# Total average test loss: 0.007938518643379211
# Model Saved!
#
# Time elapsed: 2391.640115737915
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8278939361107096
# Current batch average train loss: 0.008398840203881264
#
# Current batch: 100
# Current batch average train accuracy: 0.9082879676325358
# Current batch average train loss: 0.006127204280346632
#
# Current batch: 200
# Current batch average train accuracy: 0.8698887523306994
# Current batch average train loss: 0.007169665768742561
#
# Current batch: 300
# Current batch average train accuracy: 0.4660737513845265
# Current batch average train loss: 0.01333889365196228
#
# Total average train accuarcy: 0.672933864303995
# Total average train loss: 0.010644048138856887
#
# [ Test epoch: 35 ]
#
# Total average test accuarcy: 0.8573
# Total average test loss: 0.007418684488534927
# Model Saved!
#
# Time elapsed: 2459.984321832657
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9121772034808718
# Current batch average train loss: 0.005925435572862625
#
# Current batch: 100
# Current batch average train accuracy: 0.6931753830571834
# Current batch average train loss: 0.010725067928433418
#
# Current batch: 200
# Current batch average train accuracy: 0.9439837047335582
# Current batch average train loss: 0.005986169911921024
#
# Current batch: 300
# Current batch average train accuracy: 0.8367111883384013
# Current batch average train loss: 0.007906116545200348
#
# Total average train accuarcy: 0.6644930903847858
# Total average train loss: 0.01072019850373268
#
# [ Test epoch: 36 ]
#
# Total average test accuarcy: 0.8739
# Total average test loss: 0.007073017477989197
# Model Saved!
#
# Time elapsed: 2527.7217423915863
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6116726433513748
# Current batch average train loss: 0.011761104688048363
#
# Current batch: 100
# Current batch average train accuracy: 0.7606242159670016
# Current batch average train loss: 0.00998208299279213
#
# Current batch: 200
# Current batch average train accuracy: 0.8525609994238572
# Current batch average train loss: 0.007473648525774479
#
# Current batch: 300
# Current batch average train accuracy: 0.4419956851849097
# Current batch average train loss: 0.01301142480224371
#
# Total average train accuarcy: 0.6622218994156746
# Total average train loss: 0.01076268956542015
#
# [ Test epoch: 37 ]
#
# Total average test accuarcy: 0.8672
# Total average test loss: 0.0071607083737850186
# Model Saved!
#
# Time elapsed: 2596.0239799022675
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6313801304289252
# Current batch average train loss: 0.011453969404101372
#
# Current batch: 100
# Current batch average train accuracy: 0.47320094579581595
# Current batch average train loss: 0.013308972120285034
#
# Current batch: 200
# Current batch average train accuracy: 0.6286478296785927
# Current batch average train loss: 0.011534038931131363
#
# Current batch: 300
# Current batch average train accuracy: 0.7030933711483885
# Current batch average train loss: 0.0107902642339468
#
# Total average train accuarcy: 0.677065361097504
# Total average train loss: 0.010556510528326034
#
# [ Test epoch: 38 ]
#
# Total average test accuarcy: 0.8601
# Total average test loss: 0.0073914301455020905
# Model Saved!
#
# Time elapsed: 2663.894357919693
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4617515743115234
# Current batch average train loss: 0.013081019744277
#
# Current batch: 100
# Current batch average train accuracy: 0.7118374469303816
# Current batch average train loss: 0.010723654180765152
#
# Current batch: 200
# Current batch average train accuracy: 0.6505889855249379
# Current batch average train loss: 0.011553766205906868
#
# Current batch: 300
# Current batch average train accuracy: 0.7431995430373448
# Current batch average train loss: 0.01031123474240303
#
# Total average train accuarcy: 0.6830416332274161
# Total average train loss: 0.010434058203697204
#
# [ Test epoch: 39 ]
#
# Total average test accuarcy: 0.8581
# Total average test loss: 0.007326279038190842
# Model Saved!
#
# Time elapsed: 2732.3410351276398
#
# [ Train epoch: 40 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5089609695029885
# Current batch average train loss: 0.012799793854355812
#
# Current batch: 100
# Current batch average train accuracy: 0.6095487227400174
# Current batch average train loss: 0.011880667880177498
#
# Current batch: 200
# Current batch average train accuracy: 0.6027558341624464
# Current batch average train loss: 0.011926904320716858
#
# Current batch: 300
# Current batch average train accuracy: 0.48864715709807316
# Current batch average train loss: 0.013098054565489292
#
# Total average train accuarcy: 0.665783584670744
# Total average train loss: 0.010690100107192993
#
# [ Test epoch: 40 ]
#
# Total average test accuarcy: 0.8587
# Total average test loss: 0.007260663717985153
# Model Saved!
#
# Time elapsed: 2800.519921541214
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9242961891575002
# Current batch average train loss: 0.0062705110758543015
#
# Current batch: 100
# Current batch average train accuracy: 0.7489388874549463
# Current batch average train loss: 0.009929207153618336
#
# Current batch: 200
# Current batch average train accuracy: 0.8919388830601808
# Current batch average train loss: 0.006916144862771034
#
# Current batch: 300
# Current batch average train accuracy: 0.6879855654628514
# Current batch average train loss: 0.011280661448836327
#
# Total average train accuarcy: 0.6759683099643821
# Total average train loss: 0.010546868067979812
#
# [ Test epoch: 41 ]
#
# Total average test accuarcy: 0.8413
# Total average test loss: 0.007619094407558441
# Model Saved!
#
# Time elapsed: 2868.2947731018066
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.46015211028241165
# Current batch average train loss: 0.013934586197137833
#
# Current batch: 100
# Current batch average train accuracy: 0.7884359349366123
# Current batch average train loss: 0.009154217317700386
#
# Current batch: 200
# Current batch average train accuracy: 0.4862989473595982
# Current batch average train loss: 0.013170428574085236
#
# Current batch: 300
# Current batch average train accuracy: 0.6341159687425336
# Current batch average train loss: 0.011517437174916267
#
# Total average train accuarcy: 0.6766877692957244
# Total average train loss: 0.010535889616012574
#
# [ Test epoch: 42 ]
#
# Total average test accuarcy: 0.875
# Total average test loss: 0.007067329186201096
# Model Saved!
#
# Time elapsed: 2936.303236722946
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8245968920869595
# Current batch average train loss: 0.00847062561661005
#
# Current batch: 100
# Current batch average train accuracy: 0.5460142059666138
# Current batch average train loss: 0.01211867667734623
#
# Current batch: 200
# Current batch average train accuracy: 0.877720027236412
# Current batch average train loss: 0.006986239459365606
#
# Current batch: 300
# Current batch average train accuracy: 0.7092589194138272
# Current batch average train loss: 0.010851714760065079
#
# Total average train accuarcy: 0.6722264797385604
# Total average train loss: 0.010540021963119506
#
# [ Test epoch: 43 ]
#
# Total average test accuarcy: 0.8702
# Total average test loss: 0.007201888751983643
# Model Saved!
#
# Time elapsed: 3004.5774273872375
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7431266382878514
# Current batch average train loss: 0.009877295233309269
#
# Current batch: 100
# Current batch average train accuracy: 0.7752475621265199
# Current batch average train loss: 0.008898122236132622
#
# Current batch: 200
# Current batch average train accuracy: 0.4469946355843393
# Current batch average train loss: 0.013596538454294205
#
# Current batch: 300
# Current batch average train accuracy: 0.8396003786556064
# Current batch average train loss: 0.007559541612863541
#
# Total average train accuarcy: 0.6905820281579771
# Total average train loss: 0.010319292664527894
#
# [ Test epoch: 44 ]
#
# Total average test accuarcy: 0.871
# Total average test loss: 0.0071532329916954044
# Model Saved!
#
# Time elapsed: 3072.611445903778
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6367744100567619
# Current batch average train loss: 0.011714968830347061
#
# Current batch: 100
# Current batch average train accuracy: 0.8733167128087627
# Current batch average train loss: 0.006866419687867165
#
# Current batch: 200
# Current batch average train accuracy: 0.515391535217526
# Current batch average train loss: 0.012283491902053356
#
# Current batch: 300
# Current batch average train accuracy: 0.6454272326025258
# Current batch average train loss: 0.011326812207698822
#
# Total average train accuarcy: 0.6705491922735755
# Total average train loss: 0.010568467284440995
#
# [ Test epoch: 45 ]
#
# Total average test accuarcy: 0.874
# Total average test loss: 0.007105283695459366
# Model Saved!
#
# Time elapsed: 3140.4197545051575
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4715370698936333
# Current batch average train loss: 0.013270331546664238
#
# Current batch: 100
# Current batch average train accuracy: 0.7910139602299712
# Current batch average train loss: 0.009460892528295517
#
# Current batch: 200
# Current batch average train accuracy: 0.783083418716988
# Current batch average train loss: 0.009409754537045956
#
# Current batch: 300
# Current batch average train accuracy: 0.46638328482825625
# Current batch average train loss: 0.013417516835033894
#
# Total average train accuarcy: 0.6736378018628773
# Total average train loss: 0.010541077398061753
#
# [ Test epoch: 46 ]
#
# Total average test accuarcy: 0.8901
# Total average test loss: 0.006777560955286026
# Model Saved!
#
# Time elapsed: 3207.970680952072
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8557538654359823
# Current batch average train loss: 0.007105439901351929
#
# Current batch: 100
# Current batch average train accuracy: 0.8765226301342669
# Current batch average train loss: 0.00732703460380435
#
# Current batch: 200
# Current batch average train accuracy: 0.8662963096596025
# Current batch average train loss: 0.007376240566372871
#
# Current batch: 300
# Current batch average train accuracy: 0.5540636142787057
# Current batch average train loss: 0.012449178844690323
#
# Total average train accuarcy: 0.6780622584326106
# Total average train loss: 0.010426563574075698
#
# [ Test epoch: 47 ]
#
# Total average test accuarcy: 0.8704
# Total average test loss: 0.007102184122800827
# Model Saved!
#
# Time elapsed: 3276.042695760727
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4746887338193649
# Current batch average train loss: 0.01284232921898365
#
# Current batch: 100
# Current batch average train accuracy: 0.8541384725195905
# Current batch average train loss: 0.007657758891582489
#
# Current batch: 200
# Current batch average train accuracy: 0.8631918286386716
# Current batch average train loss: 0.006976454518735409
#
# Current batch: 300
# Current batch average train accuracy: 0.6981074025513354
# Current batch average train loss: 0.01049589179456234
#
# Total average train accuarcy: 0.6830722047190412
# Total average train loss: 0.010379328824281692
#
# [ Test epoch: 48 ]
#
# Total average test accuarcy: 0.8534
# Total average test loss: 0.007583951848745346
# Model Saved!
#
# Time elapsed: 3344.3120164871216
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7919880485989567
# Current batch average train loss: 0.00870567373931408
#
# Current batch: 100
# Current batch average train accuracy: 0.5640560955760349
# Current batch average train loss: 0.012559859082102776
#
# Current batch: 200
# Current batch average train accuracy: 0.5343257503077404
# Current batch average train loss: 0.012560813687741756
#
# Current batch: 300
# Current batch average train accuracy: 0.7966700216059351
# Current batch average train loss: 0.008735385723412037
#
# Total average train accuarcy: 0.6843883060258314
# Total average train loss: 0.010369377343654633
#
# [ Test epoch: 49 ]
#
# Total average test accuarcy: 0.8605
# Total average test loss: 0.007219387310743332
# Model Saved!
#
# Time elapsed: 3412.64777469635
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.44284978630677707
# Current batch average train loss: 0.013590779155492783
#
# Current batch: 100
# Current batch average train accuracy: 0.6111727417263962
# Current batch average train loss: 0.011488731950521469
#
# Current batch: 200
# Current batch average train accuracy: 0.749780294538702
# Current batch average train loss: 0.009966554120182991
#
# Current batch: 300
# Current batch average train accuracy: 0.6799180782482647
# Current batch average train loss: 0.010796066373586655
#
# Total average train accuarcy: 0.7061113385500808
# Total average train loss: 0.009964570722579957
#
# [ Test epoch: 50 ]
#
# Total average test accuarcy: 0.9256
# Total average test loss: 0.0061585608959198
# Model Saved!
#
# Time elapsed: 3480.6379582881927
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5527804654989061
# Current batch average train loss: 0.011835956946015358
#
# Current batch: 100
# Current batch average train accuracy: 0.5014375310576186
# Current batch average train loss: 0.011769551783800125
#
# Current batch: 200
# Current batch average train accuracy: 0.9228147185113135
# Current batch average train loss: 0.006672068499028683
#
# Current batch: 300
# Current batch average train accuracy: 0.6042750287820721
# Current batch average train loss: 0.0112864188849926
#
# Total average train accuarcy: 0.7003631579473576
# Total average train loss: 0.009925853815078736
#
# [ Test epoch: 51 ]
#
# Total average test accuarcy: 0.9308
# Total average test loss: 0.0060432922840118405
# Model Saved!
#
# Time elapsed: 3548.35582780838
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9336772953839503
# Current batch average train loss: 0.006216146983206272
#
# Current batch: 100
# Current batch average train accuracy: 0.8009184875839753
# Current batch average train loss: 0.009215799160301685
#
# Current batch: 200
# Current batch average train accuracy: 0.7450844089635578
# Current batch average train loss: 0.009976779110729694
#
# Current batch: 300
# Current batch average train accuracy: 0.755507784191462
# Current batch average train loss: 0.009699596092104912
#
# Total average train accuarcy: 0.7170315884251782
# Total average train loss: 0.009719201953411102
#
# [ Test epoch: 52 ]
#
# Total average test accuarcy: 0.9316
# Total average test loss: 0.0061774037063121795
# Model Saved!
#
# Time elapsed: 3616.6908378601074
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9251017892567714
# Current batch average train loss: 0.0064553613774478436
#
# Current batch: 100
# Current batch average train accuracy: 0.9228097022146654
# Current batch average train loss: 0.006467175669968128
#
# Current batch: 200
# Current batch average train accuracy: 0.7374930417259773
# Current batch average train loss: 0.009933670051395893
#
# Current batch: 300
# Current batch average train accuracy: 0.6515157500982776
# Current batch average train loss: 0.011019040830433369
#
# Total average train accuarcy: 0.7212803027219344
# Total average train loss: 0.009601360206604004
#
# [ Test epoch: 53 ]
#
# Total average test accuarcy: 0.9376
# Total average test loss: 0.0059462070703506465
# Model Saved!
#
# Time elapsed: 3684.855220556259
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9187301787280866
# Current batch average train loss: 0.006650349125266075
#
# Current batch: 100
# Current batch average train accuracy: 0.9379164389451365
# Current batch average train loss: 0.005815839860588312
#
# Current batch: 200
# Current batch average train accuracy: 0.5495305573378504
# Current batch average train loss: 0.012059815227985382
#
# Current batch: 300
# Current batch average train accuracy: 0.789957065560985
# Current batch average train loss: 0.0091461893171072
#
# Total average train accuarcy: 0.7287325930150379
# Total average train loss: 0.009463363060951233
#
# [ Test epoch: 54 ]
#
# Total average test accuarcy: 0.9329
# Total average test loss: 0.00609011008143425
# Model Saved!
#
# Time elapsed: 3753.2176179885864
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7657011400035924
# Current batch average train loss: 0.00896767433732748
#
# Current batch: 100
# Current batch average train accuracy: 0.8573055408639888
# Current batch average train loss: 0.00753456074744463
#
# Current batch: 200
# Current batch average train accuracy: 0.9326460510076532
# Current batch average train loss: 0.006324430927634239
#
# Current batch: 300
# Current batch average train accuracy: 0.7008810967927283
# Current batch average train loss: 0.01056629978120327
#
# Total average train accuarcy: 0.734156030256043
# Total average train loss: 0.009403378227949143
#
# [ Test epoch: 55 ]
#
# Total average test accuarcy: 0.9369
# Total average test loss: 0.005976916044950485
# Model Saved!
#
# Time elapsed: 3820.9162163734436
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9331505858507496
# Current batch average train loss: 0.006336436606943607
#
# Current batch: 100
# Current batch average train accuracy: 0.884406315683639
# Current batch average train loss: 0.007450668141245842
#
# Current batch: 200
# Current batch average train accuracy: 0.9545586934014363
# Current batch average train loss: 0.0052610523998737335
#
# Current batch: 300
# Current batch average train accuracy: 0.5692980424996457
# Current batch average train loss: 0.01209967490285635
#
# Total average train accuarcy: 0.7339597921386667
# Total average train loss: 0.00942132917523384
#
# [ Test epoch: 56 ]
#
# Total average test accuarcy: 0.9371
# Total average test loss: 0.0060206733047962185
# Model Saved!
#
# Time elapsed: 3888.8722112178802
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6651991887271999
# Current batch average train loss: 0.010774228721857071
#
# Current batch: 100
# Current batch average train accuracy: 0.7722499273020818
# Current batch average train loss: 0.009416933171451092
#
# Current batch: 200
# Current batch average train accuracy: 0.5549885370993553
# Current batch average train loss: 0.011595381423830986
#
# Current batch: 300
# Current batch average train accuracy: 0.7303107185290912
# Current batch average train loss: 0.010217217728495598
#
# Total average train accuarcy: 0.726613152431709
# Total average train loss: 0.009469885331392288
#
# [ Test epoch: 57 ]
#
# Total average test accuarcy: 0.9353
# Total average test loss: 0.0061806668639183045
# Model Saved!
#
# Time elapsed: 3956.7990884780884
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7584607606037258
# Current batch average train loss: 0.009876617230474949
#
# Current batch: 100
# Current batch average train accuracy: 0.6124337986255204
# Current batch average train loss: 0.011182697489857674
#
# Current batch: 200
# Current batch average train accuracy: 0.9415819344430789
# Current batch average train loss: 0.005808550864458084
#
# Current batch: 300
# Current batch average train accuracy: 0.6765069883491518
# Current batch average train loss: 0.010753333568572998
#
# Total average train accuarcy: 0.7347682079246861
# Total average train loss: 0.009382095628976822
#
# [ Test epoch: 58 ]
#
# Total average test accuarcy: 0.9386
# Total average test loss: 0.006104938381910324
# Model Saved!
#
# Time elapsed: 4024.981326341629
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.524321528546706
# Current batch average train loss: 0.011795992963016033
#
# Current batch: 100
# Current batch average train accuracy: 0.9731288959732568
# Current batch average train loss: 0.004719835240393877
#
# Current batch: 200
# Current batch average train accuracy: 0.7967296150991455
# Current batch average train loss: 0.009096920490264893
#
# Current batch: 300
# Current batch average train accuracy: 0.7847611299257579
# Current batch average train loss: 0.009261924773454666
#
# Total average train accuarcy: 0.7297043244445581
# Total average train loss: 0.009456173330545426
#
# [ Test epoch: 59 ]
#
# Total average test accuarcy: 0.939
# Total average test loss: 0.005946998876333237
# Model Saved!
#
# Time elapsed: 4093.007421731949
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8144807380882911
# Current batch average train loss: 0.008923156186938286
#
# Current batch: 100
# Current batch average train accuracy: 0.8821984398871403
# Current batch average train loss: 0.007316268980503082
#
# Current batch: 200
# Current batch average train accuracy: 0.6042072641318772
# Current batch average train loss: 0.011569848284125328
#
# Current batch: 300
# ...
#
# Current batch: 0
# Current batch average train accuracy: 0.7591615854626347
# Current batch average train loss: 0.009545862674713135
#
# Current batch: 100
# Current batch average train accuracy: 0.9831896494878869
# Current batch average train loss: 0.004767382051795721
#
# Current batch: 200
# Current batch average train accuracy: 0.5865460169426779
# Current batch average train loss: 0.01107453741133213
#
# Current batch: 300
# Current batch average train accuracy: 0.522356972041026
# Current batch average train loss: 0.011279607191681862
#
# Total average train accuarcy: 0.7416538325786974
# Total average train loss: 0.009100188195705414
#
# [ Test epoch: 93 ]
#
# Total average test accuarcy: 0.939
# Total average test loss: 0.005862652546167374
# Model Saved!
#
# Time elapsed: 6409.075199365616
#
# [ Train epoch: 94 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.7361456555798912
# Current batch average train loss: 0.009751427918672562
#
# Current batch: 100
# Current batch average train accuracy: 0.5103657086696405
# Current batch average train loss: 0.011710857972502708
#
# Current batch: 200
# Current batch average train accuracy: 0.7220196514908898
# Current batch average train loss: 0.010085109621286392
#
# Current batch: 300
# Current batch average train accuracy: 0.6208428587568126
# Current batch average train loss: 0.01118773315101862
#
# Total average train accuarcy: 0.7278197351697726
# Total average train loss: 0.009273345826864243
#
# [ Test epoch: 94 ]
#
# Total average test accuarcy: 0.9425
# Total average test loss: 0.0059101526319980625
# Model Saved!
#
# Time elapsed: 6476.910895109177
#
# [ Train epoch: 95 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6445667751961641
# Current batch average train loss: 0.010721491649746895
#
# Current batch: 100
# Current batch average train accuracy: 0.5614926402779903
# Current batch average train loss: 0.01167310494929552
#
# Current batch: 200
# Current batch average train accuracy: 0.785135242347328
# Current batch average train loss: 0.009298279881477356
#
# Current batch: 300
# Current batch average train accuracy: 0.794233319974358
# Current batch average train loss: 0.009190866723656654
#
# Total average train accuarcy: 0.7460401102250289
# Total average train loss: 0.009034038965702058
#
# [ Test epoch: 95 ]
#
# Total average test accuarcy: 0.9402
# Total average test loss: 0.005984016293287277
# Model Saved!
#
# Time elapsed: 6544.835052490234
#
# [ Train epoch: 96 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8178555024417771
# Current batch average train loss: 0.008772454224526882
#
# Current batch: 100
# Current batch average train accuracy: 0.619879169416832
# Current batch average train loss: 0.010781865566968918
#
# Current batch: 200
# Current batch average train accuracy: 0.7365863064892171
# Current batch average train loss: 0.009682713076472282
#
# Current batch: 300
# Current batch average train accuracy: 0.669588698902769
# Current batch average train loss: 0.01062018796801567
#
# Total average train accuarcy: 0.7397743557445831
# Total average train loss: 0.00910868196964264
#
# [ Test epoch: 96 ]
#
# Total average test accuarcy: 0.9362
# Total average test loss: 0.006198582869768142
# Model Saved!
#
# Time elapsed: 6613.222759008408
#
# [ Train epoch: 97 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5122006798253336
# Current batch average train loss: 0.011605918407440186
#
# Current batch: 100
# Current batch average train accuracy: 0.9224640697386404
# Current batch average train loss: 0.006276633124798536
#
# Current batch: 200
# Current batch average train accuracy: 0.49889885230284525
# Current batch average train loss: 0.011626663617789745
#
# Current batch: 300
# Current batch average train accuracy: 0.7549137105617534
# Current batch average train loss: 0.009716188535094261
#
# Total average train accuarcy: 0.7306954395450093
# Total average train loss: 0.00926355617403984
#
# [ Test epoch: 97 ]
#
# Total average test accuarcy: 0.9451
# Total average test loss: 0.0058714073061943055
# Model Saved!
#
# Time elapsed: 6681.342281341553
#
# [ Train epoch: 98 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.864347200977414
# Current batch average train loss: 0.007480575703084469
#
# Current batch: 100
# Current batch average train accuracy: 0.7727388102549703
# Current batch average train loss: 0.009280629456043243
#
# Current batch: 200
# Current batch average train accuracy: 0.5398839308469889
# Current batch average train loss: 0.011520647443830967
#
# Current batch: 300
# Current batch average train accuracy: 0.5521452859193136
# Current batch average train loss: 0.011125403456389904
#
# Total average train accuarcy: 0.7476248120677977
# Total average train loss: 0.009005985622406006
#
# [ Test epoch: 98 ]
#
# Total average test accuarcy: 0.9406
# Total average test loss: 0.005978958690166474
# Model Saved!
#
# Time elapsed: 6749.0970113277435
#
# [ Train epoch: 99 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9275356061123428
# Current batch average train loss: 0.006429634056985378
#
# Current batch: 100
# Current batch average train accuracy: 0.7258684224712412
# Current batch average train loss: 0.009957175701856613
#
# Current batch: 200
# Current batch average train accuracy: 0.5360428752289423
# Current batch average train loss: 0.011347574181854725
#
# Current batch: 300
# Current batch average train accuracy: 0.8520154457229927
# Current batch average train loss: 0.008083640597760677
#
# Total average train accuarcy: 0.7465089522610109
# Total average train loss: 0.009013694741725921
#
# [ Test epoch: 99 ]
#
# Total average test accuarcy: 0.9448
# Total average test loss: 0.005755919688940048
# Model Saved!
#
# Time elapsed: 6816.92270898819
#
# [ Train epoch: 100 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6647312373283001
# Current batch average train loss: 0.010773543268442154
#
# Current batch: 100
# Current batch average train accuracy: 0.5073493534934778
# Current batch average train loss: 0.011790581047534943
#
# Current batch: 200
# Current batch average train accuracy: 0.8048473309534466
# Current batch average train loss: 0.00896403193473816
#
# Current batch: 300
# Current batch average train accuracy: 0.8096117001732829
# Current batch average train loss: 0.008595366030931473
#
# Total average train accuarcy: 0.7454775896265938
# Total average train loss: 0.00897826628446579
#
# [ Test epoch: 100 ]
#
# Total average test accuarcy: 0.9489
# Total average test loss: 0.005716362124681473
# Model Saved!
#
# Time elapsed: 6885.183746099472
#
# [ Train epoch: 101 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8433702856358525
# Current batch average train loss: 0.008085031062364578
#
# Current batch: 100
# Current batch average train accuracy: 0.9244631284402094
# Current batch average train loss: 0.006410257890820503
#
# Current batch: 200
# Current batch average train accuracy: 0.5731050532136803
# Current batch average train loss: 0.011350586079061031
#
# Current batch: 300
# Current batch average train accuracy: 0.5989313821850402
# Current batch average train loss: 0.011033816263079643
#
# Total average train accuarcy: 0.7398282821876072
# Total average train loss: 0.009098620091676711
#
# [ Test epoch: 101 ]
#
# Total average test accuarcy: 0.9458
# Total average test loss: 0.006134549635648728
# Model Saved!
#
# Time elapsed: 6953.557823181152
#
# [ Train epoch: 102 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6539394509154483
# Current batch average train loss: 0.010702148079872131
#
# Current batch: 100
# Current batch average train accuracy: 0.6635568912378096
# Current batch average train loss: 0.010424424894154072
#
# Current batch: 200
# Current batch average train accuracy: 0.98586141932278
# Current batch average train loss: 0.004755326546728611
#
# Current batch: 300
# Current batch average train accuracy: 0.6102258806935894
# Current batch average train loss: 0.010795261710882187
#
# Total average train accuarcy: 0.7479225672259011
# Total average train loss: 0.008897683942317963
#
# [ Test epoch: 102 ]
#
# Total average test accuarcy: 0.9469
# Total average test loss: 0.005932162219285965
# Model Saved!
#
# Time elapsed: 7021.371389865875
#
# [ Train epoch: 103 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5652886263439174
# Current batch average train loss: 0.010759461671113968
#
# Current batch: 100
# Current batch average train accuracy: 0.8435669470118007
# Current batch average train loss: 0.00818018801510334
#
# Current batch: 200
# Current batch average train accuracy: 0.5256585089132851
# Current batch average train loss: 0.011396578513085842
#
# Current batch: 300
# Current batch average train accuracy: 0.7323073413832466
# Current batch average train loss: 0.009874721057713032
#
# Total average train accuarcy: 0.7489998448528592
# Total average train loss: 0.00885414587855339
#
# [ Test epoch: 103 ]
#
# Total average test accuarcy: 0.9489
# Total average test loss: 0.005845830273628234
# Model Saved!
#
# Time elapsed: 7089.616923093796
#
# [ Train epoch: 104 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5313077619275794
# Current batch average train loss: 0.011219071224331856
#
# Current batch: 100
# Current batch average train accuracy: 0.5348065178978487
# Current batch average train loss: 0.011102883145213127
#
# Current batch: 200
# Current batch average train accuracy: 0.7673571868527398
# Current batch average train loss: 0.009297111071646214
#
# Current batch: 300
# Current batch average train accuracy: 0.8719841760500218
# Current batch average train loss: 0.007473089266568422
#
# Total average train accuarcy: 0.7393899383043487
# Total average train loss: 0.009022632076740264
#
# [ Test epoch: 104 ]
#
# Total average test accuarcy: 0.9511
# Total average test loss: 0.005852513736486435
# Model Saved!
#
# Time elapsed: 7157.7356634140015
#
# [ Train epoch: 105 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9594616949696847
# Current batch average train loss: 0.0055414666421711445
#
# Current batch: 100
# Current batch average train accuracy: 0.8708901025235721
# Current batch average train loss: 0.007442972622811794
#
# Current batch: 200
# Current batch average train accuracy: 0.5615877889523871
# Current batch average train loss: 0.011408183723688126
#
# Current batch: 300
# Current batch average train accuracy: 0.5186656551225253
# Current batch average train loss: 0.011246450245380402
#
# Total average train accuarcy: 0.7509042966182472
# Total average train loss: 0.008829549943208694
#
# [ Test epoch: 105 ]
#
# Total average test accuarcy: 0.9499
# Total average test loss: 0.005884849643707275
# Model Saved!
#
# Time elapsed: 7226.129890680313
#
# [ Train epoch: 106 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8614963355297586
# Current batch average train loss: 0.007861156016588211
#
# Current batch: 100
# Current batch average train accuracy: 0.8048841057653305
# Current batch average train loss: 0.00870492123067379
#
# Current batch: 200
# Current batch average train accuracy: 0.5234230610184796
# Current batch average train loss: 0.011209915392100811
#
# Current batch: 300
# Current batch average train accuracy: 0.6985176208124512
# Current batch average train loss: 0.009903975762426853
#
# Total average train accuarcy: 0.7471710220218927
# Total average train loss: 0.008876299269199372
#
# [ Test epoch: 106 ]
#
# Total average test accuarcy: 0.951
# Total average test loss: 0.005737006473541259
# Model Saved!
#
# Time elapsed: 7294.30558681488
#
# [ Train epoch: 107 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5168515994334241
# Current batch average train loss: 0.011090226471424103
#
# Current batch: 100
# Current batch average train accuracy: 0.5360859250415876
# Current batch average train loss: 0.011623425409197807
#
# Current batch: 200
# Current batch average train accuracy: 0.9063404590283675
# Current batch average train loss: 0.006805816665291786
#
# Current batch: 300
# Current batch average train accuracy: 0.928121616459601
# Current batch average train loss: 0.006365320645272732
#
# Total average train accuarcy: 0.750574125462846
# Total average train loss: 0.008869184770584106
#
# [ Test epoch: 107 ]
#
# Total average test accuarcy: 0.9516
# Total average test loss: 0.0056884874701499935
# Model Saved!
#
# Time elapsed: 7362.021849155426
#
# [ Train epoch: 108 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.98917631216117
# Current batch average train loss: 0.004638997837901115
#
# Current batch: 100
# Current batch average train accuracy: 0.9084115186820316
# Current batch average train loss: 0.006894422695040703
#
# Current batch: 200
# Current batch average train accuracy: 0.5344622795434588
# Current batch average train loss: 0.011358514428138733
#
# Current batch: 300
# Current batch average train accuracy: 0.5266182635569863
# Current batch average train loss: 0.01092887856066227
#
# Total average train accuarcy: 0.7391653064002356
# Total average train loss: 0.008988407522439956
#
# [ Test epoch: 108 ]
#
# Total average test accuarcy: 0.9501
# Total average test loss: 0.005767065334320068
# Model Saved!
#
# Time elapsed: 7430.311052560806
#
# [ Train epoch: 109 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.9197107977535658
# Current batch average train loss: 0.006536588538438082
#
# Current batch: 100
# Current batch average train accuracy: 0.7949542614066227
# Current batch average train loss: 0.008928777649998665
#
# Current batch: 200
# Current batch average train accuracy: 0.8188148788259192
# Current batch average train loss: 0.00850350596010685
#
# Current batch: 300
# Current batch average train accuracy: 0.7686983272345589
# Current batch average train loss: 0.009196160361170769
#
# Total average train accuarcy: 0.7657407436662784
# Total average train loss: 0.008691419240236283
#
# [ Test epoch: 109 ]
#
# Total average test accuarcy: 0.9501
# Total average test loss: 0.00577735053896904
# Model Saved!
#
# Time elapsed: 7498.526137113571
#
# [ Train epoch: 110 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.6040795416644927
# Current batch average train loss: 0.01076910737901926
#
# Current batch: 100
# Current batch average train accuracy: 0.7219028078294406
# Current batch average train loss: 0.009663650766015053
#
# Current batch: 200
# Current batch average train accuracy: 0.8094172244875442
# Current batch average train loss: 0.00864439457654953
#
# Current batch: 300
# Current batch average train accuracy: 0.5254939339722091
# Current batch average train loss: 0.011402569711208344
#
# Total average train accuarcy: 0.7515966302966334
# Total average train loss: 0.008855159531831741
#
# [ Test epoch: 110 ]
#
# Total average test accuarcy: 0.9517
# Total average test loss: 0.005735459285974503
# Model Saved!
#
# Time elapsed: 7566.384535312653
#
# [ Train epoch: 111 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.8498010039662447
# Current batch average train loss: 0.007932139560580254
#
# Current batch: 100
# Current batch average train accuracy: 0.532323026485204
# Current batch average train loss: 0.011340063065290451
#
# Current batch: 200
# Current batch average train accuracy: 0.6124002895912595
# Current batch average train loss: 0.01105509977787733
#
# Current batch: 300
# Current batch average train accuracy: 0.8317084917406282
# Current batch average train loss: 0.008152501657605171
#
# Total average train accuarcy: 0.7454426411092102
# Total average train loss: 0.008921141279935837
#
# [ Test epoch: 111 ]
#
# Total average test accuarcy: 0.9509
# Total average test loss: 0.005937078315019608
# Model Saved!
#
# Time elapsed: 7634.726799726486
#
# [ Train epoch: 112 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5759129057965892
# Current batch average train loss: 0.011194462887942791
#
# Current batch: 100
# Current batch average train accuracy: 0.7061867991868183
# Current batch average train loss: 0.010339029133319855
#
# Current batch: 200
# Current batch average train accuracy: 0.49986972503226146
# Current batch average train loss: 0.011386247351765633
#
# Current batch: 300
# Current batch average train accuracy: 0.6371721307126371
# Current batch average train loss: 0.0107188168913126
#
# Total average train accuarcy: 0.7424354104056036
# Total average train loss: 0.00895927616238594
#
# [ Test epoch: 112 ]
#
# Total average test accuarcy: 0.9501
# Total average test loss: 0.005800938242673874
# Model Saved!
#
# Time elapsed: 7702.640766620636
#
# [ Train epoch: 113 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5773929742772905
# Current batch average train loss: 0.010600828565657139

# %% [markdown]
# ## 95% accuracy in CIFAR10 dataset with label smoothing and mixup augmentation
